# %%
import os
import io
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
import easygui
import numpy as np
import matplotlib.pyplot as plt
import requests
from datetime import datetime
import time
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from sklearn.metrics import mean_squared_error
from keras.callbacks import ModelCheckpoint

# %%
def fetch_stock_data(stock_name):
    end_date = int(datetime.now().timestamp())
    start_date = int((datetime.now() - pd.DateOffset(days=1826)).timestamp())

    url = f"https://query1.finance.yahoo.com/v7/finance/download/{stock_name}?period1={start_date}&period2={end_date}&interval=1d&events=history"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36"
    }

    retries = 3
    while retries > 0:
        try:
            response = requests.get(url, headers=headers)
            if response.status_code == 200:
                stock_data = pd.read_csv(io.StringIO(response.text))
                return stock_data
            else:
                print("Failed to fetch data")
                print(f"Status Code: {response.status_code}")
                return None
        except requests.RequestException as e:
            print(f"Request failed: {e}")
            retries -= 1
            time.sleep(2)  # Wait before retrying

    print("Maximum retries exceeded. Unable to fetch data.")
    return None
def save_to_excel(stock_data, stock_name):
    if stock_data is not None:
        stock_data.to_excel(f"Historical Data/{stock_name}.xlsx", index=False)
        print(f"Stock data for {stock_name} saved successfully to the Excel file.")

# %%
easygui.msgbox("Welcome to Our project \n Stock Price Prediction Using LSTM\n Raghav Arora 220370\nViresh Chauhan 220422", "Stock Prediction Using LSTM")
stock_name=easygui.enterbox('Please enter a stock ticker symbol')

# %%
def data_analysis():
    df=pd.read_excel(f"Historical Data/{stock_name}.xlsx")
    df.describe()
    df.info()
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)  # Set 'Date' column as the index

    # Plotting
    plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
    plt.plot(df['Adj Close'])
    plt.ylabel('Adj Close')
    plt.xlabel('Date')
    plt.title(f'Closing Price of {stock_name}')
    plt.show()
    df['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel('Date')
    plt.title(f"Sales Volume for {stock_name}")
    plt.show()
    df_daily_return = df['Adj Close'].pct_change()
    df_daily_return
    df_daily_return.plot( legend=True, linestyle='--', marker='o')
    plt.show()
    df_daily_return.hist(bins=50)
    plt.xlabel('Daily Return')
    plt.ylabel('Counts')
    plt.title(f'{stock_name}')
    plt.show()


    moving_avg = pd.read_excel(f"Historical Data/{stock_name}.xlsx")

    ma_day = [10, 20, 50]

    for ma in ma_day:
        column_name = f"MA for {ma} days"
        moving_avg[column_name] = moving_avg['Adj Close'].rolling(ma).mean()

    fig, axes = plt.subplots(nrows=1, ncols=1)
    fig.set_figheight(8)
    fig.set_figwidth(12)

    moving_avg[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes)
    axes.set_title(f'Stock Analysis for {stock_name}')

    # Adjust spacing between subplots here
    plt.subplots_adjust(wspace=0.3, hspace=0.3)  # You can modify these values as needed

    plt.show()
    closing_df = pd.read_excel(f"Historical Data/{stock_name}.xlsx")
    column_name = 'Adj Close'
    closing_df[column_name] = closing_df['Adj Close']
    closing_df['Adj Close'] = pd.to_numeric(closing_df['Adj Close'], errors='coerce')
    closing_df.dropna(subset=['Adj Close'], inplace=True)

    tech_return = closing_df['Adj Close'].pct_change()
    rets = tech_return.dropna()

    area = np.pi * 20

    plt.figure(figsize=(10, 8))
    plt.scatter(rets.mean(), rets.std(), s=area)
    plt.xlabel('Expected return')
    plt.ylabel('Risk')

    plt.annotate(rets.name, xy=(rets.mean(), rets.std()), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom',
                arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))
    plt.show()

# %%
def data_scaling(raw_data):
        scaled_data = raw_data.values.reshape(-1, 1)
        scaler=MinMaxScaler(feature_range=(0,1))
        scaled_data=scaler.fit_transform(scaled_data)
        train_dataset_len=int(np.ceil(len(scaled_data)*.80))
        train_data= scaled_data[: train_dataset_len]
        test_data=raw_data[ train_dataset_len-60:].values
        features_set = []
        labels = []
        for i in range(60, len(train_data)):
            features_set.append(train_data[i-60:i, 0])
            labels.append(train_data[i, 0])
        features_set, labels = np.array(features_set), np.array(labels)
        features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))
        return features_set,labels

# %%
def create_lstm_model(features_set):
            model = Sequential()
            model.add(LSTM(units=128, return_sequences=True, input_shape=(features_set.shape[1], 1)))
            model.add(Dropout(0.65))
            model.add(LSTM(units=64, return_sequences=True))
            model.add(Dropout(0.40))
            model.add(LSTM(units=64, return_sequences=True))
            model.add(Dropout(0.40))
            model.add(LSTM(units=32))
            model.add(Dropout(0.40))
            model.add(Dense(units=1))
            model.compile(optimizer='adam', loss='mean_squared_error')
            return model

# %%
def model_performance_analysis(model,features_set,labels,history):
            from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
            predictions = model.predict(features_set)
            mse = mean_squared_error(labels, predictions)
            mae = mean_absolute_error(labels, predictions)
            r2 = r2_score(labels, predictions)
            print(f'Mean Squared Error: {mse}')
            print(f'Mean Absolute Error: {mae}')
            print(f'R-squared Score: {r2}') 
            plt.plot(history.history['loss'])
            plt.plot(history.history['val_loss'])
            plt.title('Model Loss') 
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.legend(['Train', 'Validation'], loc='upper right')
            plt.show()

# %%
def model_training():        
        raw_data=pd.read_excel(f'Historical Data/{stock_name}.xlsx')['Adj Close']
        features_set,labels= data_scaling(raw_data)

        # Create the LSTM model
        model = create_lstm_model(features_set)

        validation_split = 0.2 
        split_index = int(len(features_set) * (1 - validation_split))
        train_features, val_features = features_set[:split_index], features_set[split_index:]
        train_labels, val_labels = labels[:split_index], labels[split_index:]

        mc = ModelCheckpoint(f'Models/LSTM({stock_name}).hdf5', monitor='loss', verbose=1, save_best_only=True, mode='min')
        # Train the model
        history = model.fit(train_features,train_labels, epochs=700, batch_size=192,callbacks=[mc],validation_data=(val_features, val_labels))
        model_performance_analysis(model,features_set,labels,history)

# %%
def predictions(n):
        model=load_model(f'Models/LSTM({stock_name}).hdf5')
        df=pd.read_excel(f'Historical Data/{stock_name}.xlsx')
        data=df.filter(['Close'])
        scaled_data = data.values.reshape(-1, 1)
        scaler=MinMaxScaler(feature_range=(0,1))
        scaled_data=scaler.fit_transform(scaled_data)
        train_dataset_len=int(np.ceil(len(scaled_data)*.85))
        test_data = scaled_data[train_dataset_len - 60: , :]
        x_test = []
        x_test.append(test_data[-60:])
        x_test = np.array(x_test)
        x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
        predictions = []
        for _ in range(n):
                # Predict the next day
                prediction = model.predict(x_test)
                
                # Append the prediction to the results
                predictions.append(prediction[0, 0])

                # Update x_test for the next prediction
                x_test = np.roll(x_test, -1, axis=1)
                x_test[0, -1, 0] = prediction
        # Inverse transform the predictions to get actual stock prices
        predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
        plt.plot(predictions)
        plt.xlabel("Number Of Days")
        plt.ylabel("Stock Price")
        plt.show  
        easygui.msgbox( predictions, "Prediction for the next days")

# %%
if(os.path.isfile(f'Models/LSTM({stock_name}).hdf5') and os.path.isfile(f'Historical Data/{stock_name}.xlsx')):
    x=easygui.boolbox("A model for this stock is found do you wish to use that(yes) or create a new model(no)" ,'' ,('Continue with the previous model', 'Create a new model'))
    if(x):
        n=easygui.integerbox("Enter the number of days you would like to predict the data for: ")
        predictions(n)
    else:
        data = fetch_stock_data(stock_name)
        if data is not None:
            save_to_excel(data, stock_name)
        else:
            print("Data retrieval failed or invalid ticker symbol provided.")
        data_analysis()
        model_training()
        n=easygui.integerbox("Enter the number of days you would like to predict the data for: ")
        predictions(n)
else:
    data = fetch_stock_data(stock_name)
    if data is not None:
        save_to_excel(data, stock_name)
    else:
        print("Data retrieval failed or invalid ticker symbol provided.")
    data_analysis()
    model_training()
    n=easygui.integerbox("Enter the number of days you would like to predict the data for: ")
    predictions(n)
# Out:
# Stock data for AAPL saved successfully to the Excel file.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB
# WARNING:tensorflow:From c:\Users\nisha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\nisha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/700
# WARNING:tensorflow:From c:\Users\nisha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 4/4 [==============================] - ETA: 0s - loss: 0.1166
# Epoch 1: loss improved from inf to 0.11656, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 8s 752ms/step - loss: 0.1166 - val_loss: 0.0688
# Epoch 2/700
# c:\Users\nisha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - ETA: 0s - loss: 0.0427
# Epoch 2: loss improved from 0.11656 to 0.04271, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 268ms/step - loss: 0.0427 - val_loss: 0.0339
# Epoch 3/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0309
# Epoch 3: loss improved from 0.04271 to 0.03092, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 257ms/step - loss: 0.0309 - val_loss: 0.0435
# Epoch 4/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0205
# Epoch 4: loss improved from 0.03092 to 0.02052, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 276ms/step - loss: 0.0205 - val_loss: 0.0041
# Epoch 5/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 5: loss improved from 0.02052 to 0.01851, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0185 - val_loss: 0.0035
# Epoch 6/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 6: loss improved from 0.01851 to 0.01397, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 228ms/step - loss: 0.0140 - val_loss: 0.0179
# Epoch 7/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0128
# Epoch 7: loss improved from 0.01397 to 0.01280, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 222ms/step - loss: 0.0128 - val_loss: 0.0036
# Epoch 8/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0117
# Epoch 8: loss improved from 0.01280 to 0.01170, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0117 - val_loss: 0.0047
# Epoch 9/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 9: loss improved from 0.01170 to 0.01110, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 221ms/step - loss: 0.0111 - val_loss: 0.0045
# Epoch 10/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 10: loss improved from 0.01110 to 0.00994, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 226ms/step - loss: 0.0099 - val_loss: 0.0037
# Epoch 11/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 11: loss did not improve from 0.00994
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0102 - val_loss: 0.0035
# Epoch 12/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 12: loss improved from 0.00994 to 0.00849, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0085 - val_loss: 0.0046
# Epoch 13/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 13: loss did not improve from 0.00849
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0092 - val_loss: 0.0033
# Epoch 14/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 14: loss improved from 0.00849 to 0.00828, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 258ms/step - loss: 0.0083 - val_loss: 0.0035
# Epoch 15/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 15: loss did not improve from 0.00828
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0089 - val_loss: 0.0042
# Epoch 16/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 16: loss improved from 0.00828 to 0.00821, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0082 - val_loss: 0.0036
# Epoch 17/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 17: loss did not improve from 0.00821
# 4/4 [==============================] - 1s 225ms/step - loss: 0.0083 - val_loss: 0.0033
# Epoch 18/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 18: loss did not improve from 0.00821
# 4/4 [==============================] - 1s 251ms/step - loss: 0.0087 - val_loss: 0.0041
# Epoch 19/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 19: loss did not improve from 0.00821
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0086 - val_loss: 0.0053
# Epoch 20/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 20: loss did not improve from 0.00821
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0085 - val_loss: 0.0040
# Epoch 21/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 21: loss did not improve from 0.00821
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0090 - val_loss: 0.0033
# Epoch 22/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 22: loss improved from 0.00821 to 0.00772, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0077 - val_loss: 0.0035
# Epoch 23/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 23: loss did not improve from 0.00772
# 4/4 [==============================] - 1s 221ms/step - loss: 0.0084 - val_loss: 0.0034
# Epoch 24/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 24: loss did not improve from 0.00772
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0086 - val_loss: 0.0035
# Epoch 25/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 25: loss did not improve from 0.00772
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0081 - val_loss: 0.0035
# Epoch 26/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 26: loss did not improve from 0.00772
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0078 - val_loss: 0.0043
# Epoch 27/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 27: loss improved from 0.00772 to 0.00750, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 28/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 28: loss did not improve from 0.00750
# 4/4 [==============================] - 1s 205ms/step - loss: 0.0078 - val_loss: 0.0032
# Epoch 29/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 29: loss improved from 0.00750 to 0.00743, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 222ms/step - loss: 0.0074 - val_loss: 0.0033
# Epoch 30/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 30: loss did not improve from 0.00743
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 31/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 31: loss improved from 0.00743 to 0.00722, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0072 - val_loss: 0.0031
# Epoch 32/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 32: loss did not improve from 0.00722
# 4/4 [==============================] - 1s 218ms/step - loss: 0.0083 - val_loss: 0.0031
# Epoch 33/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 33: loss did not improve from 0.00722
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0075 - val_loss: 0.0040
# Epoch 34/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 34: loss did not improve from 0.00722
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0077 - val_loss: 0.0036
# Epoch 35/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 35: loss improved from 0.00722 to 0.00666, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 224ms/step - loss: 0.0067 - val_loss: 0.0041
# Epoch 36/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 36: loss did not improve from 0.00666
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0079 - val_loss: 0.0037
# Epoch 37/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 37: loss improved from 0.00666 to 0.00657, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 222ms/step - loss: 0.0066 - val_loss: 0.0039
# Epoch 38/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 38: loss did not improve from 0.00657
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0066 - val_loss: 0.0039
# Epoch 39/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 39: loss did not improve from 0.00657
# 4/4 [==============================] - 1s 272ms/step - loss: 0.0069 - val_loss: 0.0038
# Epoch 40/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 40: loss did not improve from 0.00657
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0071 - val_loss: 0.0031
# Epoch 41/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 41: loss did not improve from 0.00657
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0067 - val_loss: 0.0032
# Epoch 42/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 42: loss did not improve from 0.00657
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0068 - val_loss: 0.0032
# Epoch 43/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 43: loss did not improve from 0.00657
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0067 - val_loss: 0.0032
# Epoch 44/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 44: loss improved from 0.00657 to 0.00650, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0065 - val_loss: 0.0031
# Epoch 45/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 45: loss improved from 0.00650 to 0.00593, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 266ms/step - loss: 0.0059 - val_loss: 0.0030
# Epoch 46/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 46: loss improved from 0.00593 to 0.00580, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0058 - val_loss: 0.0030
# Epoch 47/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 47: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0064 - val_loss: 0.0035
# Epoch 48/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 48: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 255ms/step - loss: 0.0068 - val_loss: 0.0034
# Epoch 49/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 49: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 50/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 50: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0077 - val_loss: 0.0030
# Epoch 51/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 51: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0063 - val_loss: 0.0030
# Epoch 52/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 52: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0062 - val_loss: 0.0030
# Epoch 53/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 53: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 227ms/step - loss: 0.0059 - val_loss: 0.0031
# Epoch 54/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 54: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0061 - val_loss: 0.0030
# Epoch 55/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 55: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 226ms/step - loss: 0.0059 - val_loss: 0.0030
# Epoch 56/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 56: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0059 - val_loss: 0.0030
# Epoch 57/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 57: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0060 - val_loss: 0.0037
# Epoch 58/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 58: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 205ms/step - loss: 0.0070 - val_loss: 0.0032
# Epoch 59/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 59: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 204ms/step - loss: 0.0063 - val_loss: 0.0039
# Epoch 60/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 60: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0060 - val_loss: 0.0032
# Epoch 61/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 61: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0065 - val_loss: 0.0047
# Epoch 62/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 62: loss did not improve from 0.00580
# 4/4 [==============================] - 1s 264ms/step - loss: 0.0070 - val_loss: 0.0037
# Epoch 63/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 63: loss improved from 0.00580 to 0.00564, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0056 - val_loss: 0.0043
# Epoch 64/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 64: loss did not improve from 0.00564
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0065 - val_loss: 0.0036
# Epoch 65/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 65: loss did not improve from 0.00564
# 4/4 [==============================] - 1s 280ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 66/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 66: loss improved from 0.00564 to 0.00517, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 67/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 67: loss did not improve from 0.00517
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0062 - val_loss: 0.0044
# Epoch 68/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 68: loss did not improve from 0.00517
# 4/4 [==============================] - 1s 257ms/step - loss: 0.0067 - val_loss: 0.0035
# Epoch 69/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 69: loss did not improve from 0.00517
# 4/4 [==============================] - 1s 276ms/step - loss: 0.0065 - val_loss: 0.0038
# Epoch 70/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 70: loss did not improve from 0.00517
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0063 - val_loss: 0.0030
# Epoch 71/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 71: loss did not improve from 0.00517
# 4/4 [==============================] - 1s 204ms/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 72/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 72: loss did not improve from 0.00517
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0062 - val_loss: 0.0028
# Epoch 73/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 73: loss did not improve from 0.00517
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0059 - val_loss: 0.0031
# Epoch 74/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 74: loss did not improve from 0.00517
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0052 - val_loss: 0.0029
# Epoch 75/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 75: loss improved from 0.00517 to 0.00514, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0051 - val_loss: 0.0028
# Epoch 76/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 76: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0061 - val_loss: 0.0028
# Epoch 77/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 77: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 78/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 78: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0056 - val_loss: 0.0028
# Epoch 79/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 79: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 199ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 80/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 80: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0055 - val_loss: 0.0028
# Epoch 81/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 81: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0063 - val_loss: 0.0028
# Epoch 82/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 82: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 83/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 83: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0063 - val_loss: 0.0034
# Epoch 84/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 84: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0062 - val_loss: 0.0030
# Epoch 85/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 85: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 204ms/step - loss: 0.0057 - val_loss: 0.0027
# Epoch 86/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 86: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0058 - val_loss: 0.0029
# Epoch 87/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 87: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0054 - val_loss: 0.0028
# Epoch 88/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 88: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0060 - val_loss: 0.0028
# Epoch 89/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 89: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 189ms/step - loss: 0.0059 - val_loss: 0.0030
# Epoch 90/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 90: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0055 - val_loss: 0.0029
# Epoch 91/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 91: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0053 - val_loss: 0.0027
# Epoch 92/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 92: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 220ms/step - loss: 0.0058 - val_loss: 0.0030
# Epoch 93/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 93: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 203ms/step - loss: 0.0055 - val_loss: 0.0027
# Epoch 94/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 94: loss did not improve from 0.00514
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0054 - val_loss: 0.0027
# Epoch 95/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 95: loss improved from 0.00514 to 0.00475, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0047 - val_loss: 0.0027
# Epoch 96/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 96: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0058 - val_loss: 0.0027
# Epoch 97/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 97: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 98/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 98: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0057 - val_loss: 0.0029
# Epoch 99/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 99: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 220ms/step - loss: 0.0054 - val_loss: 0.0026
# Epoch 100/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 100: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 215ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 101/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 101: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 102/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 102: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 199ms/step - loss: 0.0056 - val_loss: 0.0031
# Epoch 103/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 103: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0056 - val_loss: 0.0028
# Epoch 104/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 104: loss did not improve from 0.00475
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 105/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 105: loss improved from 0.00475 to 0.00448, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 258ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 106/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 106: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 226ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 107/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 107: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0058 - val_loss: 0.0026
# Epoch 108/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 108: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0048 - val_loss: 0.0029
# Epoch 109/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 109: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 257ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 110/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 110: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0050 - val_loss: 0.0030
# Epoch 111/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 111: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 112/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 112: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0049 - val_loss: 0.0026
# Epoch 113/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 113: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0051 - val_loss: 0.0028
# Epoch 114/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 114: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 255ms/step - loss: 0.0052 - val_loss: 0.0029
# Epoch 115/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 115: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 265ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 116/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 116: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 117/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 117: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0055 - val_loss: 0.0028
# Epoch 118/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 118: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0047 - val_loss: 0.0028
# Epoch 119/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 119: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 120/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 120: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0051 - val_loss: 0.0028
# Epoch 121/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 121: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 122/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 122: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0055 - val_loss: 0.0037
# Epoch 123/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 123: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 124/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 124: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 125/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 125: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 272ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 126/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 126: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 275ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 127/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 127: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 252ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 128/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 128: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0049 - val_loss: 0.0029
# Epoch 129/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 129: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 130/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 130: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 131/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 131: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0049 - val_loss: 0.0029
# Epoch 132/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 132: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0050 - val_loss: 0.0029
# Epoch 133/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 133: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 134/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 134: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 278ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 135/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 135: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 268ms/step - loss: 0.0050 - val_loss: 0.0030
# Epoch 136/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 136: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 253ms/step - loss: 0.0055 - val_loss: 0.0038
# Epoch 137/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 137: loss did not improve from 0.00448
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0051 - val_loss: 0.0028
# Epoch 138/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 138: loss improved from 0.00448 to 0.00434, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 139/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 139: loss did not improve from 0.00434
# 4/4 [==============================] - 1s 264ms/step - loss: 0.0049 - val_loss: 0.0029
# Epoch 140/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 140: loss improved from 0.00434 to 0.00433, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 268ms/step - loss: 0.0043 - val_loss: 0.0028
# Epoch 141/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 141: loss did not improve from 0.00433
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 142/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 142: loss did not improve from 0.00433
# 4/4 [==============================] - 1s 247ms/step - loss: 0.0045 - val_loss: 0.0029
# Epoch 143/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 143: loss did not improve from 0.00433
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 144/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 144: loss improved from 0.00433 to 0.00426, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 260ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 145/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 145: loss did not improve from 0.00426
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0047 - val_loss: 0.0023
# Epoch 146/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 146: loss did not improve from 0.00426
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0044 - val_loss: 0.0028
# Epoch 147/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 147: loss did not improve from 0.00426
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0050 - val_loss: 0.0023
# Epoch 148/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 148: loss did not improve from 0.00426
# 4/4 [==============================] - 1s 251ms/step - loss: 0.0046 - val_loss: 0.0024
# Epoch 149/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 149: loss did not improve from 0.00426
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 150/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 150: loss did not improve from 0.00426
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0044 - val_loss: 0.0023
# Epoch 151/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 151: loss improved from 0.00426 to 0.00408, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 256ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 152/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 152: loss did not improve from 0.00408
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0042 - val_loss: 0.0024
# Epoch 153/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 153: loss did not improve from 0.00408
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0046 - val_loss: 0.0032
# Epoch 154/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 154: loss did not improve from 0.00408
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0050 - val_loss: 0.0029
# Epoch 155/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 155: loss improved from 0.00408 to 0.00406, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 260ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 156/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 156: loss did not improve from 0.00406
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0046 - val_loss: 0.0030
# Epoch 157/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 157: loss did not improve from 0.00406
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 158/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 158: loss did not improve from 0.00406
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 159/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 159: loss did not improve from 0.00406
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0045 - val_loss: 0.0030
# Epoch 160/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 160: loss did not improve from 0.00406
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 161/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 161: loss did not improve from 0.00406
# 4/4 [==============================] - 1s 247ms/step - loss: 0.0041 - val_loss: 0.0026
# Epoch 162/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 162: loss improved from 0.00406 to 0.00365, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 163/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 163: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0046 - val_loss: 0.0024
# Epoch 164/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 164: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 165/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 165: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0042 - val_loss: 0.0024
# Epoch 166/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 166: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 167/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 167: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0041 - val_loss: 0.0025
# Epoch 168/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 168: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 169/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 169: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 170/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 170: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0044 - val_loss: 0.0027
# Epoch 171/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 171: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0045 - val_loss: 0.0036
# Epoch 172/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 172: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 173/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 173: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 174/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 174: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 175/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 175: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 176/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 176: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0041 - val_loss: 0.0026
# Epoch 177/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 177: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0041 - val_loss: 0.0027
# Epoch 178/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 178: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 179/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 179: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 180/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 180: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 181/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 181: loss improved from 0.00365 to 0.00365, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 182/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 182: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0043 - val_loss: 0.0026
# Epoch 183/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 183: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 184/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 184: loss did not improve from 0.00365
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0041 - val_loss: 0.0025
# Epoch 185/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 185: loss improved from 0.00365 to 0.00349, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 186/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 186: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 187/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 187: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 188/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 188: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 189/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 189: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0040 - val_loss: 0.0027
# Epoch 190/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 190: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 191/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 191: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0040 - val_loss: 0.0024
# Epoch 192/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 192: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 193/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 193: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 194/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 194: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 195/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 195: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 196/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 196: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0042 - val_loss: 0.0024
# Epoch 197/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 197: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 198/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 198: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 199/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 199: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 200/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 200: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 201/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 201: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 202/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 202: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 203/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 203: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0042 - val_loss: 0.0024
# Epoch 204/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 204: loss did not improve from 0.00349
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 205/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 205: loss improved from 0.00349 to 0.00342, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 206/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 206: loss did not improve from 0.00342
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 207/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 207: loss did not improve from 0.00342
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 208/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 208: loss did not improve from 0.00342
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 209/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 209: loss did not improve from 0.00342
# 4/4 [==============================] - 1s 228ms/step - loss: 0.0043 - val_loss: 0.0027
# Epoch 210/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 210: loss did not improve from 0.00342
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0042 - val_loss: 0.0027
# Epoch 211/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 211: loss did not improve from 0.00342
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 212/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 212: loss did not improve from 0.00342
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 213/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 213: loss improved from 0.00342 to 0.00341, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 214/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 214: loss improved from 0.00341 to 0.00323, saving model to Models\LSTM(AAPL).hdf5
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 215/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 215: loss did not improve from 0.00323
# 4/4 [==============================] - 1s 228ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 216/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 216: loss did not improve from 0.00323
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0039 - val_loss: 0.0025
# ...
# Epoch 629/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 629: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 630/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 630: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 192ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 631/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 631: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 193ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 632/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 632: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 633/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 633: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 634/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 634: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 635/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 635: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 636/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 636: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 637/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 637: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 638/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 638: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 639/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 639: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 640/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 640: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 641/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 641: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 259ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 642/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 642: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 273ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 643/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 643: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 263ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 644/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 644: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 257ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 645/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 645: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 646/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 646: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 647/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 647: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 225ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 648/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 648: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 225ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 649/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 649: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 224ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 650/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 650: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 228ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 651/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 651: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 652/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 652: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 230ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 653/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 653: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 226ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 654/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 654: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 655/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 655: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 656/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 656: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 232ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 657/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 657: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 658/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 658: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 659/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 659: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 660/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 660: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 221ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 661/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 661: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 228ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 662/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 662: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 663/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 663: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 226ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 664/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 664: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 227ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 665/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 665: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 224ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 666/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 666: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 224ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 667/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 667: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 668/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 668: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 228ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 669/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 669: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 670/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 670: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 247ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 671/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 671: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 672/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 672: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 219ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 673/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 673: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 222ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 674/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 674: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 221ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 675/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 675: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 214ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 676/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 676: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 677/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 677: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 187ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 678/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 678: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 186ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 679/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 679: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 680/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 680: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 681/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 681: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 682/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 682: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 186ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 683/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 683: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 684/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 684: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 186ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 685/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 685: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 185ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 686/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 686: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 687/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 687: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 189ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 688/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 688: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 187ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 689/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 689: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 186ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 690/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 690: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 691/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 691: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 191ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 692/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 692: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 189ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 693/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 693: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 694/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 694: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 695/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 695: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 190ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 696/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 696: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 697/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 697: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 185ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 698/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 698: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 186ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 699/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 699: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 700/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 700: loss did not improve from 0.00177
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0022 - val_loss: 0.0015
# 30/30 [==============================] - 2s 22ms/step
# Mean Squared Error: 0.0007998449587973855
# Mean Absolute Error: 0.022017426093524237
# R-squared Score: 0.9873367751255563
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# C:\Users\nisha\AppData\Local\Temp\ipykernel_2028\657129417.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0, -1, 0] = prediction
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
