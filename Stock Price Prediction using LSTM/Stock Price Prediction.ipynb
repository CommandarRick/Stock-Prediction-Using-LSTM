# %%
import os
import io
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
import easygui
import numpy as np
import matplotlib.pyplot as plt
import requests
from datetime import datetime
import time
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from sklearn.metrics import mean_squared_error
from keras.callbacks import ModelCheckpoint

# %%
def fetch_stock_data(stock_name):
    end_date = int(datetime.now().timestamp())
    start_date = int((datetime.now() - pd.DateOffset(days=1826)).timestamp())

    url = f"https://query1.finance.yahoo.com/v7/finance/download/{stock_name}?period1={start_date}&period2={end_date}&interval=1d&events=history"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36"
    }

    retries = 3
    while retries > 0:
        try:
            response = requests.get(url, headers=headers)
            if response.status_code == 200:
                stock_data = pd.read_csv(io.StringIO(response.text))
                return stock_data
            else:
                print("Failed to fetch data")
                print(f"Status Code: {response.status_code}")
                return None
        except requests.RequestException as e:
            print(f"Request failed: {e}")
            retries -= 1
            time.sleep(2)  # Wait before retrying

    print("Maximum retries exceeded. Unable to fetch data.")
    return None
def save_to_excel(stock_data, stock_name):
    if stock_data is not None:
        stock_data.to_excel(f"Historical Data/{stock_name}.xlsx", index=False)
        print(f"Stock data for {stock_name} saved successfully to the Excel file.")

# %%
easygui.msgbox("Welcome to Our project \n Stock Price Prediction Using LSTM\n Raghav Arora 220370\nViresh Chauhan 220422", "Stock Prediction Using LSTM")
stock_name=easygui.enterbox('Please enter a stock ticker symbol')

# %%
def data_analysis():
    df=pd.read_excel(f"Historical Data/{stock_name}.xlsx")
    df.describe()
    df.info()
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)  # Set 'Date' column as the index

    # Plotting
    plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
    plt.plot(df['Adj Close'])
    plt.ylabel('Adj Close')
    plt.xlabel('Date')
    plt.title(f'Closing Price of {stock_name}')
    plt.show()
    df['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel('Date')
    plt.title(f"Sales Volume for {stock_name}")
    plt.show()
    df_daily_return = df['Adj Close'].pct_change()
    df_daily_return
    df_daily_return.plot( legend=True, linestyle='--', marker='o')
    plt.show()
    df_daily_return.hist(bins=50)
    plt.xlabel('Daily Return')
    plt.ylabel('Counts')
    plt.title(f'{stock_name}')
    plt.show()


    moving_avg = pd.read_excel(f"Historical Data/{stock_name}.xlsx")

    ma_day = [10, 20, 50]

    for ma in ma_day:
        column_name = f"MA for {ma} days"
        moving_avg[column_name] = moving_avg['Adj Close'].rolling(ma).mean()

    fig, axes = plt.subplots(nrows=1, ncols=1)
    fig.set_figheight(8)
    fig.set_figwidth(12)
    plt.xlabel('No of days')
    plt.ylabel('Moving average')

    moving_avg[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes)
    axes.set_title(f'Stock Analysis for {stock_name}')

    # Adjust spacing between subplots here
    plt.subplots_adjust(wspace=0.3, hspace=0.3)  # You can modify these values as needed

    plt.show()
    closing_df = pd.read_excel(f"Historical Data/{stock_name}.xlsx")
    column_name = 'Adj Close'
    closing_df[column_name] = closing_df['Adj Close']
    closing_df['Adj Close'] = pd.to_numeric(closing_df['Adj Close'], errors='coerce')
    closing_df.dropna(subset=['Adj Close'], inplace=True)

    tech_return = closing_df['Adj Close'].pct_change()
    rets = tech_return.dropna()

    area = np.pi * 20

    plt.figure(figsize=(10, 8))
    plt.scatter(rets.mean(), rets.std(), s=area)
    plt.xlabel('Expected return')
    plt.ylabel('Risk')

    plt.annotate(rets.name, xy=(rets.mean(), rets.std()), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom',
                arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))
    plt.show()

# %%
def data_scaling(raw_data):
        scaled_data = raw_data.values.reshape(-1, 1)
        scaler=MinMaxScaler(feature_range=(0,1))
        scaled_data=scaler.fit_transform(scaled_data)
        train_dataset_len=int(np.ceil(len(scaled_data)*.80))
        train_data= scaled_data[: train_dataset_len]
       
        features_set = []
        labels = []
        for i in range(60, len(train_data)):
            features_set.append(train_data[i-60:i, 0])
            labels.append(train_data[i, 0])
        features_set, labels = np.array(features_set), np.array(labels)
        features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))
        return features_set,labels

# %%
def create_lstm_model(features_set):
            model = Sequential()
            model.add(LSTM(units=128, return_sequences=True, input_shape=(features_set.shape[1], 1)))
            model.add(Dropout(0.65))
            model.add(LSTM(units=64, return_sequences=True))
            model.add(Dropout(0.40))
            model.add(LSTM(units=64, return_sequences=True))
            model.add(Dropout(0.40))
            model.add(LSTM(units=32))
            model.add(Dropout(0.40))
            model.add(Dense(units=1))
            model.compile(optimizer='adam', loss='mean_squared_error')
            return model

# %%
def model_performance_analysis(model,features_set,labels,history):
            from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
            predictions = model.predict(features_set)
            mse = mean_squared_error(labels, predictions)
            mae = mean_absolute_error(labels, predictions)
            r2 = r2_score(labels, predictions)
            print(f'Mean Squared Error: {mse}')
            print(f'Mean Absolute Error: {mae}')
            print(f'R-squared Score: {r2}') 
            plt.plot(history.history['loss'])
            plt.plot(history.history['val_loss'])
            plt.title('Model Loss') 
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.legend(['Train', 'Validation'], loc='upper right')
            plt.show()

# %%
def model_training():        
        raw_data=pd.read_excel(f'Historical Data/{stock_name}.xlsx')['Adj Close']
        features_set,labels= data_scaling(raw_data)

        # Create the LSTM model
        model = create_lstm_model(features_set)

        validation_split = 0.2 
        split_index = int(len(features_set) * (1 - validation_split))
        train_features, val_features = features_set[:split_index], features_set[split_index:]
        train_labels, val_labels = labels[:split_index], labels[split_index:]

        mc = ModelCheckpoint(f'Models/LSTM({stock_name}).hdf5', monitor='loss', verbose=1, save_best_only=True, mode='min')
        # Train the model
        history = model.fit(train_features,train_labels, epochs=700, batch_size=192,callbacks=[mc],validation_data=(val_features, val_labels))
        model_performance_analysis(model,features_set,labels,history)

# %%
def predictions(n):
        model=load_model(f'Models/LSTM({stock_name}).hdf5')
        df=pd.read_excel(f'Historical Data/{stock_name}.xlsx')
        data=df.filter(['Adj Close'])
        scaled_data = data.values.reshape(-1, 1)
        scaler=MinMaxScaler(feature_range=(0,1))
        scaled_data=scaler.fit_transform(scaled_data)
        train_dataset_len=int(np.ceil(len(scaled_data)*.80))
        test_data = scaled_data[train_dataset_len - 60: , :]
        x_test = []
        x_test.append(test_data[-60:])
        x_test = np.array(x_test)
        x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
        predictions = []
        for _ in range(n):
                # Predict the next day
                prediction = model.predict(x_test)
                
                # Append the prediction to the results
                predictions.append(prediction[0, 0])

                # Update x_test for the next prediction
                x_test = np.roll(x_test, -1, axis=1)
                x_test[0, -1, 0] = prediction
        # Inverse transform the predictions to get actual stock prices
        predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
        plt.plot(predictions)
        plt.xlabel("Number Of Days")
        plt.ylabel("Stock Price")
        plt.show  
        easygui.msgbox( predictions, "Prediction for the next days")

# %%
if(os.path.isfile(f'Models/LSTM({stock_name}).hdf5') and os.path.isfile(f'Historical Data/{stock_name}.xlsx')):
    x=easygui.boolbox("A model for this stock is found do you wish to use that(yes) or create a new model(no)" ,'' ,('Continue with the previous model', 'Create a new model'))
    if(x):
        n=easygui.integerbox("Enter the number of days you would like to predict the data for: ")
        predictions(n)
    else:
        data = fetch_stock_data(stock_name)
        if data is not None:
            save_to_excel(data, stock_name)
        else:
            print("Data retrieval failed or invalid ticker symbol provided.")
        data_analysis()
        model_training()
        n=easygui.integerbox("Enter the number of days you would like to predict the data for: ")
        predictions(n)
else:
    data = fetch_stock_data(stock_name)
    if data is not None:
        save_to_excel(data, stock_name)
    else:
        print("Data retrieval failed or invalid ticker symbol provided.")
    data_analysis()
    model_training()
    n=easygui.integerbox("Enter the number of days you would like to predict the data for: ")
    predictions(n)
# Out:
# Stock data for TATAMOTORS.NS saved successfully to the Excel file.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1236 non-null   object
#  1   Open       1236 non-null   float64
#  2   High       1236 non-null   float64
#  3   Low        1236 non-null   float64
#  4   Close      1236 non-null   float64
#  5   Adj Close  1236 non-null   float64
#  6   Volume     1236 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 67.7+ KB
# Epoch 1/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0511
# Epoch 1: loss improved from inf to 0.05107, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 8s 765ms/step - loss: 0.0511 - val_loss: 0.0363
# Epoch 2/700
# c:\Users\rking\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - ETA: 0s - loss: 0.0205
# Epoch 2: loss improved from 0.05107 to 0.02051, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 299ms/step - loss: 0.0205 - val_loss: 0.0496
# Epoch 3/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 3: loss improved from 0.02051 to 0.02041, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 266ms/step - loss: 0.0204 - val_loss: 0.0248
# Epoch 4/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0105
# Epoch 4: loss improved from 0.02041 to 0.01047, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0105 - val_loss: 0.0047
# Epoch 5/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 5: loss did not improve from 0.01047
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0115 - val_loss: 0.0028
# Epoch 6/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 6: loss improved from 0.01047 to 0.00796, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 272ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 7/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 7: loss improved from 0.00796 to 0.00681, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0068 - val_loss: 0.0035
# Epoch 8/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 8: loss improved from 0.00681 to 0.00641, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0064 - val_loss: 0.0027
# Epoch 9/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 9: loss did not improve from 0.00641
# 4/4 [==============================] - 1s 273ms/step - loss: 0.0066 - val_loss: 0.0033
# Epoch 10/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 10: loss improved from 0.00641 to 0.00597, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0060 - val_loss: 0.0014
# Epoch 11/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 11: loss did not improve from 0.00597
# 4/4 [==============================] - 1s 275ms/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 12/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 12: loss did not improve from 0.00597
# 4/4 [==============================] - 1s 261ms/step - loss: 0.0060 - val_loss: 0.0017
# Epoch 13/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 13: loss improved from 0.00597 to 0.00593, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0059 - val_loss: 0.0017
# Epoch 14/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 14: loss improved from 0.00593 to 0.00508, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 15/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 15: loss did not improve from 0.00508
# 4/4 [==============================] - 1s 265ms/step - loss: 0.0057 - val_loss: 0.0011
# Epoch 16/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 16: loss did not improve from 0.00508
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 17/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 17: loss improved from 0.00508 to 0.00500, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0050 - val_loss: 0.0016
# Epoch 18/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 18: loss improved from 0.00500 to 0.00438, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0044 - val_loss: 0.0011
# Epoch 19/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 19: loss did not improve from 0.00438
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0050 - val_loss: 0.0023
# Epoch 20/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 20: loss did not improve from 0.00438
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0048 - val_loss: 0.0010
# Epoch 21/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 21: loss did not improve from 0.00438
# 4/4 [==============================] - 1s 332ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 22/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 22: loss did not improve from 0.00438
# 4/4 [==============================] - 1s 368ms/step - loss: 0.0050 - val_loss: 0.0022
# Epoch 23/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 23: loss did not improve from 0.00438
# 4/4 [==============================] - 2s 544ms/step - loss: 0.0050 - val_loss: 9.8945e-04
# Epoch 24/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 24: loss did not improve from 0.00438
# 4/4 [==============================] - 2s 490ms/step - loss: 0.0048 - val_loss: 0.0012
# Epoch 25/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 25: loss did not improve from 0.00438
# 4/4 [==============================] - 2s 404ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 26/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 26: loss improved from 0.00438 to 0.00417, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 27/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 27: loss did not improve from 0.00417
# 4/4 [==============================] - 2s 471ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 28/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 28: loss did not improve from 0.00417
# 4/4 [==============================] - 2s 484ms/step - loss: 0.0047 - val_loss: 9.4662e-04
# Epoch 29/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 29: loss did not improve from 0.00417
# 4/4 [==============================] - 2s 476ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 30/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 30: loss did not improve from 0.00417
# 4/4 [==============================] - 2s 407ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 31/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 31: loss improved from 0.00417 to 0.00406, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 2s 493ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 32/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 32: loss did not improve from 0.00406
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 33/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 33: loss did not improve from 0.00406
# 4/4 [==============================] - 1s 311ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 34/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 34: loss did not improve from 0.00406
# 4/4 [==============================] - 2s 447ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 35/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 35: loss did not improve from 0.00406
# 4/4 [==============================] - 2s 557ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 36/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 36: loss did not improve from 0.00406
# 4/4 [==============================] - 2s 515ms/step - loss: 0.0042 - val_loss: 9.1139e-04
# Epoch 37/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 37: loss improved from 0.00406 to 0.00371, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 2s 532ms/step - loss: 0.0037 - val_loss: 9.7816e-04
# Epoch 38/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 38: loss improved from 0.00371 to 0.00370, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 2s 429ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 39/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 39: loss did not improve from 0.00370
# 4/4 [==============================] - 1s 350ms/step - loss: 0.0038 - val_loss: 8.9289e-04
# Epoch 40/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 40: loss did not improve from 0.00370
# 4/4 [==============================] - 1s 355ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 41/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 41: loss did not improve from 0.00370
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 42/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 42: loss improved from 0.00370 to 0.00360, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 2s 554ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 43/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 43: loss did not improve from 0.00360
# 4/4 [==============================] - 2s 401ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 44/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 44: loss did not improve from 0.00360
# 4/4 [==============================] - 1s 388ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 45/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 45: loss did not improve from 0.00360
# 4/4 [==============================] - 1s 333ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 46/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 46: loss did not improve from 0.00360
# 4/4 [==============================] - 1s 324ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 47/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 47: loss improved from 0.00360 to 0.00342, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 351ms/step - loss: 0.0034 - val_loss: 9.3633e-04
# Epoch 48/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 48: loss did not improve from 0.00342
# 4/4 [==============================] - 2s 480ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 49/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 49: loss did not improve from 0.00342
# 4/4 [==============================] - 2s 569ms/step - loss: 0.0037 - val_loss: 8.5716e-04
# Epoch 50/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 50: loss did not improve from 0.00342
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0036 - val_loss: 0.0010
# Epoch 51/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 51: loss did not improve from 0.00342
# 4/4 [==============================] - 2s 531ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 52/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 52: loss did not improve from 0.00342
# 4/4 [==============================] - 2s 551ms/step - loss: 0.0035 - val_loss: 8.4053e-04
# Epoch 53/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 53: loss did not improve from 0.00342
# 4/4 [==============================] - 2s 556ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 54/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 54: loss improved from 0.00342 to 0.00322, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 2s 588ms/step - loss: 0.0032 - val_loss: 8.3908e-04
# Epoch 55/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 55: loss did not improve from 0.00322
# 4/4 [==============================] - 2s 562ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 56/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 56: loss did not improve from 0.00322
# 4/4 [==============================] - 2s 536ms/step - loss: 0.0040 - val_loss: 8.5454e-04
# Epoch 57/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 57: loss did not improve from 0.00322
# 4/4 [==============================] - 2s 539ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 58/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 58: loss did not improve from 0.00322
# 4/4 [==============================] - 2s 546ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 59/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 59: loss did not improve from 0.00322
# 4/4 [==============================] - 2s 573ms/step - loss: 0.0033 - val_loss: 8.4284e-04
# Epoch 60/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 60: loss did not improve from 0.00322
# 4/4 [==============================] - 2s 525ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 61/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 61: loss improved from 0.00322 to 0.00313, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 62/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 62: loss did not improve from 0.00313
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 63/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 63: loss did not improve from 0.00313
# 4/4 [==============================] - 2s 582ms/step - loss: 0.0033 - val_loss: 8.5056e-04
# Epoch 64/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 64: loss did not improve from 0.00313
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0043 - val_loss: 7.7782e-04
# Epoch 65/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 65: loss did not improve from 0.00313
# 4/4 [==============================] - 3s 680ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 66/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 66: loss did not improve from 0.00313
# 4/4 [==============================] - 3s 687ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 67/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 67: loss did not improve from 0.00313
# 4/4 [==============================] - 3s 695ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 68/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 68: loss did not improve from 0.00313
# 4/4 [==============================] - 3s 686ms/step - loss: 0.0033 - val_loss: 9.4389e-04
# Epoch 69/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 69: loss did not improve from 0.00313
# 4/4 [==============================] - 3s 699ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 70/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 70: loss did not improve from 0.00313
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 71/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 71: loss did not improve from 0.00313
# 4/4 [==============================] - 3s 698ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 72/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 72: loss did not improve from 0.00313
# 4/4 [==============================] - 3s 692ms/step - loss: 0.0034 - val_loss: 7.3394e-04
# Epoch 73/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 73: loss improved from 0.00313 to 0.00294, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 3s 722ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 74/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 74: loss improved from 0.00294 to 0.00271, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 3s 736ms/step - loss: 0.0027 - val_loss: 7.8525e-04
# Epoch 75/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 75: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 693ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 76/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 76: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 688ms/step - loss: 0.0035 - val_loss: 7.1862e-04
# Epoch 77/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 77: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 703ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 78/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 78: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 79/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 79: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 696ms/step - loss: 0.0032 - val_loss: 8.7125e-04
# Epoch 80/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 80: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 697ms/step - loss: 0.0032 - val_loss: 9.1528e-04
# Epoch 81/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 81: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 696ms/step - loss: 0.0030 - val_loss: 7.1567e-04
# Epoch 82/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 82: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 697ms/step - loss: 0.0029 - val_loss: 0.0010
# Epoch 83/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 83: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0030 - val_loss: 7.8592e-04
# Epoch 84/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 84: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 701ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 85/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 85: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 660ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 86/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 86: loss did not improve from 0.00271
# 4/4 [==============================] - 2s 616ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 87/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 87: loss did not improve from 0.00271
# 4/4 [==============================] - 3s 697ms/step - loss: 0.0031 - val_loss: 7.2369e-04
# Epoch 88/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 88: loss did not improve from 0.00271
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0036 - val_loss: 8.8527e-04
# Epoch 89/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 89: loss did not improve from 0.00271
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 90/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 90: loss did not improve from 0.00271
# 4/4 [==============================] - 1s 322ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 91/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 91: loss did not improve from 0.00271
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0028 - val_loss: 8.0232e-04
# Epoch 92/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 92: loss improved from 0.00271 to 0.00265, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 328ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 93/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 93: loss did not improve from 0.00265
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0029 - val_loss: 8.6410e-04
# Epoch 94/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 94: loss did not improve from 0.00265
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 95/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 95: loss improved from 0.00265 to 0.00256, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 326ms/step - loss: 0.0026 - val_loss: 7.8717e-04
# Epoch 96/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 96: loss did not improve from 0.00256
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 97/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 97: loss did not improve from 0.00256
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0031 - val_loss: 7.9290e-04
# Epoch 98/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 98: loss did not improve from 0.00256
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0028 - val_loss: 7.7889e-04
# Epoch 99/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 99: loss did not improve from 0.00256
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0027 - val_loss: 7.7010e-04
# Epoch 100/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 100: loss improved from 0.00256 to 0.00248, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 332ms/step - loss: 0.0025 - val_loss: 7.5625e-04
# Epoch 101/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 101: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0031 - val_loss: 7.7901e-04
# Epoch 102/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 102: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 311ms/step - loss: 0.0029 - val_loss: 6.5975e-04
# Epoch 103/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 103: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0029 - val_loss: 6.7166e-04
# Epoch 104/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 104: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 105/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 105: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0028 - val_loss: 7.0756e-04
# Epoch 106/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 106: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0025 - val_loss: 7.8396e-04
# Epoch 107/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 107: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 305ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 108/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 108: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 304ms/step - loss: 0.0025 - val_loss: 7.7159e-04
# Epoch 109/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 109: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 110/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 110: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0029 - val_loss: 7.0716e-04
# Epoch 111/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 111: loss did not improve from 0.00248
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0028 - val_loss: 9.7791e-04
# Epoch 112/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 112: loss improved from 0.00248 to 0.00243, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0024 - val_loss: 7.1464e-04
# Epoch 113/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 113: loss did not improve from 0.00243
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0024 - val_loss: 8.6430e-04
# Epoch 114/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 114: loss did not improve from 0.00243
# 4/4 [==============================] - 1s 304ms/step - loss: 0.0026 - val_loss: 7.3062e-04
# Epoch 115/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 115: loss did not improve from 0.00243
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0031 - val_loss: 6.5296e-04
# Epoch 116/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 116: loss did not improve from 0.00243
# 4/4 [==============================] - 1s 309ms/step - loss: 0.0026 - val_loss: 7.6787e-04
# Epoch 117/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 117: loss did not improve from 0.00243
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0025 - val_loss: 6.5614e-04
# Epoch 118/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 118: loss improved from 0.00243 to 0.00236, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0024 - val_loss: 6.4053e-04
# Epoch 119/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 119: loss did not improve from 0.00236
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0024 - val_loss: 7.2240e-04
# Epoch 120/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 120: loss did not improve from 0.00236
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0025 - val_loss: 6.2520e-04
# Epoch 121/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 121: loss did not improve from 0.00236
# 4/4 [==============================] - 1s 304ms/step - loss: 0.0026 - val_loss: 6.3141e-04
# Epoch 122/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 122: loss improved from 0.00236 to 0.00231, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 314ms/step - loss: 0.0023 - val_loss: 6.2182e-04
# Epoch 123/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 123: loss did not improve from 0.00231
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0027 - val_loss: 8.3665e-04
# Epoch 124/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 124: loss improved from 0.00231 to 0.00221, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 337ms/step - loss: 0.0022 - val_loss: 6.3380e-04
# Epoch 125/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 125: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0026 - val_loss: 6.1506e-04
# Epoch 126/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 126: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 127/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 127: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0028 - val_loss: 7.5186e-04
# Epoch 128/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 128: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 309ms/step - loss: 0.0028 - val_loss: 6.3753e-04
# Epoch 129/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 129: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 317ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 130/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 130: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 311ms/step - loss: 0.0025 - val_loss: 5.7948e-04
# Epoch 131/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 131: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0022 - val_loss: 9.0389e-04
# Epoch 132/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 132: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0024 - val_loss: 5.9747e-04
# Epoch 133/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 133: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 134/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 134: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0025 - val_loss: 5.9227e-04
# Epoch 135/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 135: loss did not improve from 0.00221
# 4/4 [==============================] - 1s 328ms/step - loss: 0.0025 - val_loss: 5.9940e-04
# Epoch 136/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 136: loss improved from 0.00221 to 0.00205, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 325ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 137/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 137: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 299ms/step - loss: 0.0025 - val_loss: 6.1263e-04
# Epoch 138/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 138: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0028 - val_loss: 9.9190e-04
# Epoch 139/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 139: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0024 - val_loss: 6.8362e-04
# Epoch 140/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 140: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0021 - val_loss: 5.7236e-04
# Epoch 141/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 141: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0027 - val_loss: 6.5585e-04
# Epoch 142/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 142: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0025 - val_loss: 9.4077e-04
# Epoch 143/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 143: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0024 - val_loss: 5.7451e-04
# Epoch 144/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 144: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 324ms/step - loss: 0.0027 - val_loss: 6.8478e-04
# Epoch 145/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 145: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 321ms/step - loss: 0.0022 - val_loss: 8.9603e-04
# Epoch 146/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 146: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0024 - val_loss: 5.5729e-04
# Epoch 147/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 147: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 311ms/step - loss: 0.0022 - val_loss: 7.1962e-04
# Epoch 148/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 148: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0023 - val_loss: 5.5364e-04
# Epoch 149/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 149: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0023 - val_loss: 8.8784e-04
# Epoch 150/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 150: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 314ms/step - loss: 0.0023 - val_loss: 5.6404e-04
# Epoch 151/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 151: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0021 - val_loss: 5.7072e-04
# Epoch 152/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 152: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0021 - val_loss: 5.9103e-04
# Epoch 153/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 153: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0021 - val_loss: 6.1076e-04
# Epoch 154/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 154: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0022 - val_loss: 6.6088e-04
# Epoch 155/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 155: loss did not improve from 0.00205
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0023 - val_loss: 6.5286e-04
# Epoch 156/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 156: loss improved from 0.00205 to 0.00197, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 328ms/step - loss: 0.0020 - val_loss: 5.8554e-04
# Epoch 157/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 157: loss did not improve from 0.00197
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0021 - val_loss: 6.2218e-04
# Epoch 158/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 158: loss did not improve from 0.00197
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 159/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 159: loss did not improve from 0.00197
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0021 - val_loss: 5.7230e-04
# Epoch 160/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch
loss did not improve from 0.00110
# 4/4 [==============================] - 1s 271ms/step - loss: 0.0013 - val_loss: 4.1976e-04
# Epoch 676/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 676: loss did not improve from 0.00110
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0012 - val_loss: 4.5567e-04
# Epoch 677/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 677: loss did not improve from 0.00110
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0013 - val_loss: 2.8722e-04
# Epoch 678/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 678: loss did not improve from 0.00110
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0012 - val_loss: 6.4905e-04
# Epoch 679/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 679: loss did not improve from 0.00110
# 4/4 [==============================] - 1s 275ms/step - loss: 0.0014 - val_loss: 2.6996e-04
# Epoch 680/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 680: loss did not improve from 0.00110
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0013 - val_loss: 2.7037e-04
# Epoch 681/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 681: loss did not improve from 0.00110
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0013 - val_loss: 2.8922e-04
# Epoch 682/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 682: loss did not improve from 0.00110
# 4/4 [==============================] - 1s 260ms/step - loss: 0.0013 - val_loss: 3.9132e-04
# Epoch 683/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 683: loss did not improve from 0.00110
# 4/4 [==============================] - 1s 302ms/step - loss: 0.0013 - val_loss: 4.3519e-04
# Epoch 684/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 684: loss improved from 0.00110 to 0.00104, saving model to Models\LSTM(TATAMOTORS.NS).hdf5
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0010 - val_loss: 2.7459e-04
# Epoch 685/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 685: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0013 - val_loss: 4.9287e-04
# Epoch 686/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 686: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0012 - val_loss: 2.7362e-04
# Epoch 687/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 687: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0013 - val_loss: 3.3046e-04
# Epoch 688/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 688: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 271ms/step - loss: 0.0013 - val_loss: 2.7362e-04
# Epoch 689/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 689: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 273ms/step - loss: 0.0014 - val_loss: 3.6909e-04
# Epoch 690/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 690: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0011 - val_loss: 2.8489e-04
# Epoch 691/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 691: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 260ms/step - loss: 0.0012 - val_loss: 4.8577e-04
# Epoch 692/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 692: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0012 - val_loss: 2.6701e-04
# Epoch 693/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 693: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0012 - val_loss: 2.7273e-04
# Epoch 694/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 694: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 275ms/step - loss: 0.0012 - val_loss: 2.7102e-04
# Epoch 695/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 695: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0014 - val_loss: 2.7499e-04
# Epoch 696/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 696: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0013 - val_loss: 2.9460e-04
# Epoch 697/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 697: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0013 - val_loss: 3.7438e-04
# Epoch 698/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 698: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 302ms/step - loss: 0.0011 - val_loss: 2.8970e-04
# Epoch 699/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 699: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0012 - val_loss: 2.6947e-04
# Epoch 700/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 700: loss did not improve from 0.00104
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0013 - val_loss: 3.6451e-04
# 30/30 [==============================] - 2s 22ms/step
# Mean Squared Error: 0.000461139481628139
# Mean Absolute Error: 0.01711194533562812
# R-squared Score: 0.9893737178204592
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# C:\Users\rking\AppData\Local\Temp\ipykernel_12868\1306884537.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0, -1, 0] = prediction
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
