# %% [markdown]
# Importing all the necessary libraries and functions used further.

# %%
import requests
import pandas as pd
from datetime import datetime
import time
import requests
import pandas as pd
from datetime import datetime
import time
import io
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
# Out:
# WARNING:tensorflow:From c:\Users\rking\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Defining a function fetch_stock_data that makes use of web scraping to fetch historical stock data from yahoo finance for a specific company that the users chooses (for demonstration purposes we are currently using stock data for Apple(AAPL)).
# The data is then saved to an Excel file in the save_to_excel function which are both being called by the main function

# %%
def fetch_stock_data(stock_name):
    end_date = int(datetime.now().timestamp())
    start_date = int((datetime.now() - pd.DateOffset(days=1826)).timestamp())

    url = f"https://query1.finance.yahoo.com/v7/finance/download/{stock_name}?period1={start_date}&period2={end_date}&interval=1d&events=history"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36"
    }

    retries = 3
    while retries > 0:
        try:
            response = requests.get(url, headers=headers)
            if response.status_code == 200:
                stock_data = pd.read_csv(io.StringIO(response.text))
                return stock_data
            else:
                print("Failed to fetch data")
                print(f"Status Code: {response.status_code}")
                return None
        except requests.RequestException as e:
            print(f"Request failed: {e}")
            retries -= 1
            time.sleep(2)  # Wait before retrying

    print("Maximum retries exceeded. Unable to fetch data.")
    return None

def save_to_excel(stock_data, stock_name):
    if stock_data is not None:
        stock_data.to_excel(f"Historical Data/{stock_name}.xlsx", index=False)
        print(f"Stock data for {stock_name} saved successfully to the Excel file.")

if __name__ == "__main__":
    stock_name = input("Enter the stock ticker symbol: ")
    data = fetch_stock_data(stock_name)
    if data is not None:
        save_to_excel(data, stock_name)
    else:
        print("Data retrieval failed or invalid ticker symbol provided.")
# Out:
# Stock data for GOOG saved successfully to the Excel file.

# %% [markdown]
# Now we can define a dataframe that reads the excel file and we can do some data analysis on the existing data to identify what parameters we want to train our LSTM model on.
# Firstly we analyze the Adjusted Close and Volume trends for the company by making various plots

# %%
df=pd.read_excel(f"Historical Data/{stock_name}.xlsx")
df.describe()
df.info()
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)  # Set 'Date' column as the index

# Plotting
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(df['Adj Close'])
plt.ylabel('Adj Close')
plt.xlabel('Date')
plt.title(f'Closing Price of {stock_name}')
plt.show()
df['Volume'].plot()
plt.ylabel('Volume')
plt.xlabel('Date')
plt.title(f"Sales Volume for {stock_name}")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   object
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 69.0+ KB

# %% [markdown]
# Now we identify the daily return of the stock by using .pct_change() function which tells us how much of a daily difference here was in the adjusted close price

# %%
df_daily_return = df['Adj Close'].pct_change()
df_daily_return
df_daily_return.plot( legend=True, linestyle='--', marker='o')
plt.show()
df_daily_return.hist(bins=50)
plt.xlabel('Daily Return')
plt.ylabel('Counts')
plt.title(f'{stock_name}')
plt.show()

# %% [markdown]
# Now we plot the moving average for the stock over 10,20 and 50 days.

# %%
moving_avg = pd.read_excel(f"Historical Data/{stock_name}.xlsx")

ma_day = [10, 20, 50]

for ma in ma_day:
    column_name = f"MA for {ma} days"
    moving_avg[column_name] = moving_avg['Adj Close'].rolling(ma).mean()

fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_figheight(8)
fig.set_figwidth(12)

moving_avg[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes)
axes.set_title(f'Stock Analysis for {stock_name}')

# Adjust spacing between subplots here
plt.subplots_adjust(wspace=0.3, hspace=0.3)  # You can modify these values as needed

plt.show()

# %% [markdown]
# Finally we plot the expected return and the risk involved in investing the partiular stock

# %%
closing_df = pd.read_excel(f"Historical Data/{stock_name}.xlsx")
column_name = 'Adj Close'
closing_df[column_name] = closing_df['Adj Close']
closing_df['Adj Close'] = pd.to_numeric(closing_df['Adj Close'], errors='coerce')
closing_df.dropna(subset=['Adj Close'], inplace=True)

tech_return = closing_df['Adj Close'].pct_change()
rets = tech_return.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 8))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

plt.annotate(rets.name, xy=(rets.mean(), rets.std()), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom',
             arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))
# Out:
# Text(50, 50, 'Adj Close')

# %% [markdown]
# Now we select the 'Adj Close' column to train our LSTM on, we would try and predict the future pries of the stock based on this data, we select this as our training data.

# %%
training_data=pd.read_excel(f'Historical Data/{stock_name}.xlsx')['Adj Close']
training_data
# Out:
# 0        50.826500
# 1        51.435501
# 2        51.150501
# 3        50.470501
# 4        48.977001
#            ...
# 1254    134.699997
# 1255    133.639999
# 1256    133.970001
# 1257    133.199997
# 1258    133.839996
# Name: Adj Close, Length: 1259, dtype: float64

# %% [markdown]
# We now have to reshape the data to fit in our lstm model, we first change the model shape to a numpy array of size(-1,1) and then use min ax scaller to transform the data to shape (0,1) which will then go into our LSTM

# %%
scaled_data = training_data.values.reshape(-1, 1)
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(scaled_data)
scaled_data
# Out:
# array([[0.01977957],
#        [0.02575615],
#        [0.02295923],
#        ...,
#        [0.83572789],
#        [0.82817128],
#        [0.83445206]])

# %% [markdown]
# Defining a feature set array that stores

# %%
features_set = []
labels = []
for i in range(60, len(scaled_data)):
    features_set.append(scaled_data[i-60:i, 0])
    labels.append(scaled_data[i, 0])
features_set, labels = np.array(features_set), np.array(labels)

# %%
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))

# %%
# Create a new array containing scaled values from index 1543 to 2002
df=pd.read_excel(f'Historical Data/{stock_name}.xlsx')
data=df.filter(['Close'])
dataset=data.values
train_dataset_len=int(np.ceil(len(dataset)*.85))
test_data = scaled_data[train_dataset_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[train_dataset_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from sklearn.metrics import mean_squared_error
from keras.callbacks import ModelCheckpoint

def create_lstm_model():
    model = Sequential()
    model.add(LSTM(units=128, return_sequences=True, input_shape=(features_set.shape[1], 1)))
    model.add(Dropout(0.65))
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dropout(0.40))
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dropout(0.40))
    model.add(LSTM(units=32))
    model.add(Dropout(0.40))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Assuming you have scaled_data available
input_shape = (scaled_data.shape[1], 1)

# Create the LSTM model
lstm_model = create_lstm_model()

validation_split = 0.2 
split_index = int(len(features_set) * (1 - validation_split))
train_features, val_features = features_set[:split_index], features_set[split_index:]
train_labels, val_labels = labels[:split_index], labels[split_index:]

mc = ModelCheckpoint(f'LSTM({stock_name}).hdf5', monitor='loss', verbose=1, save_best_only=True, mode='min')
# Train the model
history = lstm_model.fit(features_set, labels, epochs=700, batch_size=392,callbacks=[mc],validation_data=(val_features, val_labels))
# Out:
# WARNING:tensorflow:From c:\Users\rking\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\rking\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/700
# WARNING:tensorflow:From c:\Users\rking\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 4/4 [==============================] - ETA: 0s - loss: 0.2023
# Epoch 1: loss improved from inf to 0.20227, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 27s 2s/step - loss: 0.2023 - val_loss: 0.0232
# Epoch 2/700
# c:\Users\rking\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - ETA: 0s - loss: 0.0482
# Epoch 2: loss improved from 0.20227 to 0.04822, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 909ms/step - loss: 0.0482 - val_loss: 0.0288
# Epoch 3/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0352
# Epoch 3: loss improved from 0.04822 to 0.03524, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 868ms/step - loss: 0.0352 - val_loss: 0.0269
# Epoch 4/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0268
# Epoch 4: loss improved from 0.03524 to 0.02679, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 848ms/step - loss: 0.0268 - val_loss: 0.0072
# Epoch 5/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0276
# Epoch 5: loss did not improve from 0.02679
# 4/4 [==============================] - 3s 700ms/step - loss: 0.0276 - val_loss: 0.0046
# Epoch 6/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0193
# Epoch 6: loss improved from 0.02679 to 0.01932, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 729ms/step - loss: 0.0193 - val_loss: 0.0139
# Epoch 7/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 7: loss improved from 0.01932 to 0.01866, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 730ms/step - loss: 0.0187 - val_loss: 0.0031
# Epoch 8/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 8: loss improved from 0.01866 to 0.01679, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 914ms/step - loss: 0.0168 - val_loss: 0.0032
# Epoch 9/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 9: loss improved from 0.01679 to 0.01599, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 784ms/step - loss: 0.0160 - val_loss: 0.0097
# Epoch 10/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 10: loss did not improve from 0.01599
# 4/4 [==============================] - 3s 737ms/step - loss: 0.0165 - val_loss: 0.0033
# Epoch 11/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 11: loss did not improve from 0.01599
# 4/4 [==============================] - 4s 887ms/step - loss: 0.0164 - val_loss: 0.0050
# Epoch 12/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 12: loss improved from 0.01599 to 0.01505, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 1s/step - loss: 0.0150 - val_loss: 0.0056
# Epoch 13/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 13: loss improved from 0.01505 to 0.01500, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 863ms/step - loss: 0.0150 - val_loss: 0.0032
# Epoch 14/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 14: loss improved from 0.01500 to 0.01456, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 850ms/step - loss: 0.0146 - val_loss: 0.0048
# Epoch 15/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 15: loss did not improve from 0.01456
# 4/4 [==============================] - 4s 957ms/step - loss: 0.0150 - val_loss: 0.0031
# Epoch 16/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0151
# Epoch 16: loss did not improve from 0.01456
# 4/4 [==============================] - 4s 903ms/step - loss: 0.0151 - val_loss: 0.0051
# Epoch 17/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 17: loss improved from 0.01456 to 0.01376, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 899ms/step - loss: 0.0138 - val_loss: 0.0051
# Epoch 18/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 18: loss did not improve from 0.01376
# 4/4 [==============================] - 3s 801ms/step - loss: 0.0158 - val_loss: 0.0061
# Epoch 19/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 19: loss improved from 0.01376 to 0.01331, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 888ms/step - loss: 0.0133 - val_loss: 0.0030
# Epoch 20/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 20: loss did not improve from 0.01331
# 4/4 [==============================] - 4s 838ms/step - loss: 0.0141 - val_loss: 0.0088
# Epoch 21/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 21: loss did not improve from 0.01331
# 4/4 [==============================] - 4s 877ms/step - loss: 0.0148 - val_loss: 0.0030
# Epoch 22/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 22: loss did not improve from 0.01331
# 4/4 [==============================] - 4s 920ms/step - loss: 0.0163 - val_loss: 0.0051
# Epoch 23/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 23: loss did not improve from 0.01331
# 4/4 [==============================] - 3s 835ms/step - loss: 0.0150 - val_loss: 0.0070
# Epoch 24/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0128
# Epoch 24: loss improved from 0.01331 to 0.01281, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 779ms/step - loss: 0.0128 - val_loss: 0.0033
# Epoch 25/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 25: loss did not improve from 0.01281
# 4/4 [==============================] - 3s 784ms/step - loss: 0.0130 - val_loss: 0.0055
# Epoch 26/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 26: loss did not improve from 0.01281
# 4/4 [==============================] - 3s 846ms/step - loss: 0.0130 - val_loss: 0.0034
# Epoch 27/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 27: loss did not improve from 0.01281
# 4/4 [==============================] - 3s 784ms/step - loss: 0.0134 - val_loss: 0.0035
# Epoch 28/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0125
# Epoch 28: loss improved from 0.01281 to 0.01248, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 815ms/step - loss: 0.0125 - val_loss: 0.0044
# Epoch 29/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 29: loss improved from 0.01248 to 0.01208, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 817ms/step - loss: 0.0121 - val_loss: 0.0031
# Epoch 30/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 30: loss did not improve from 0.01208
# 4/4 [==============================] - 3s 784ms/step - loss: 0.0126 - val_loss: 0.0045
# Epoch 31/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 31: loss improved from 0.01208 to 0.01034, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 804ms/step - loss: 0.0103 - val_loss: 0.0031
# Epoch 32/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 32: loss did not improve from 0.01034
# 4/4 [==============================] - 3s 792ms/step - loss: 0.0110 - val_loss: 0.0053
# Epoch 33/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 33: loss did not improve from 0.01034
# 4/4 [==============================] - 4s 976ms/step - loss: 0.0118 - val_loss: 0.0043
# Epoch 34/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 34: loss did not improve from 0.01034
# 4/4 [==============================] - 3s 804ms/step - loss: 0.0121 - val_loss: 0.0030
# Epoch 35/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 35: loss did not improve from 0.01034
# 4/4 [==============================] - 4s 940ms/step - loss: 0.0110 - val_loss: 0.0032
# Epoch 36/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 36: loss did not improve from 0.01034
# 4/4 [==============================] - 4s 933ms/step - loss: 0.0109 - val_loss: 0.0030
# Epoch 37/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 37: loss did not improve from 0.01034
# 4/4 [==============================] - 4s 864ms/step - loss: 0.0108 - val_loss: 0.0044
# Epoch 38/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 38: loss did not improve from 0.01034
# 4/4 [==============================] - 5s 1s/step - loss: 0.0109 - val_loss: 0.0035
# Epoch 39/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 39: loss did not improve from 0.01034
# 4/4 [==============================] - 6s 1s/step - loss: 0.0110 - val_loss: 0.0037
# Epoch 40/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 40: loss improved from 0.01034 to 0.00996, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 0.0100 - val_loss: 0.0037
# Epoch 41/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 41: loss did not improve from 0.00996
# 4/4 [==============================] - 4s 1s/step - loss: 0.0112 - val_loss: 0.0031
# Epoch 42/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 42: loss did not improve from 0.00996
# 4/4 [==============================] - 5s 1s/step - loss: 0.0113 - val_loss: 0.0054
# Epoch 43/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 43: loss did not improve from 0.00996
# 4/4 [==============================] - 5s 1s/step - loss: 0.0115 - val_loss: 0.0074
# Epoch 44/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 44: loss did not improve from 0.00996
# 4/4 [==============================] - 4s 995ms/step - loss: 0.0133 - val_loss: 0.0042
# Epoch 45/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0122
# Epoch 45: loss did not improve from 0.00996
# 4/4 [==============================] - 5s 1s/step - loss: 0.0122 - val_loss: 0.0028
# Epoch 46/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 46: loss did not improve from 0.00996
# 4/4 [==============================] - 4s 1s/step - loss: 0.0115 - val_loss: 0.0054
# Epoch 47/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 47: loss did not improve from 0.00996
# 4/4 [==============================] - 4s 873ms/step - loss: 0.0110 - val_loss: 0.0032
# Epoch 48/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 48: loss did not improve from 0.00996
# 4/4 [==============================] - 5s 1s/step - loss: 0.0104 - val_loss: 0.0034
# Epoch 49/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 49: loss did not improve from 0.00996
# 4/4 [==============================] - 4s 925ms/step - loss: 0.0110 - val_loss: 0.0033
# Epoch 50/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 50: loss did not improve from 0.00996
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0104 - val_loss: 0.0049
# Epoch 51/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 51: loss did not improve from 0.00996
# 4/4 [==============================] - 3s 768ms/step - loss: 0.0112 - val_loss: 0.0032
# Epoch 52/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 52: loss did not improve from 0.00996
# 4/4 [==============================] - 3s 734ms/step - loss: 0.0102 - val_loss: 0.0047
# Epoch 53/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 53: loss did not improve from 0.00996
# 4/4 [==============================] - 3s 753ms/step - loss: 0.0113 - val_loss: 0.0028
# Epoch 54/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 54: loss improved from 0.00996 to 0.00940, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 1s/step - loss: 0.0094 - val_loss: 0.0035
# Epoch 55/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 55: loss did not improve from 0.00940
# 4/4 [==============================] - 3s 749ms/step - loss: 0.0102 - val_loss: 0.0032
# Epoch 56/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 56: loss did not improve from 0.00940
# 4/4 [==============================] - 4s 965ms/step - loss: 0.0104 - val_loss: 0.0032
# Epoch 57/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 57: loss did not improve from 0.00940
# 4/4 [==============================] - 4s 940ms/step - loss: 0.0103 - val_loss: 0.0039
# Epoch 58/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 58: loss did not improve from 0.00940
# 4/4 [==============================] - 4s 931ms/step - loss: 0.0096 - val_loss: 0.0028
# Epoch 59/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 59: loss did not improve from 0.00940
# 4/4 [==============================] - 4s 891ms/step - loss: 0.0112 - val_loss: 0.0034
# Epoch 60/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 60: loss improved from 0.00940 to 0.00928, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 872ms/step - loss: 0.0093 - val_loss: 0.0044
# Epoch 61/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 61: loss did not improve from 0.00928
# 4/4 [==============================] - 4s 839ms/step - loss: 0.0103 - val_loss: 0.0028
# Epoch 62/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 62: loss did not improve from 0.00928
# 4/4 [==============================] - 4s 860ms/step - loss: 0.0101 - val_loss: 0.0081
# Epoch 63/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 63: loss did not improve from 0.00928
# 4/4 [==============================] - 4s 1s/step - loss: 0.0118 - val_loss: 0.0031
# Epoch 64/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 64: loss did not improve from 0.00928
# 4/4 [==============================] - 4s 944ms/step - loss: 0.0130 - val_loss: 0.0074
# Epoch 65/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 65: loss did not improve from 0.00928
# 4/4 [==============================] - 3s 785ms/step - loss: 0.0136 - val_loss: 0.0028
# Epoch 66/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 66: loss did not improve from 0.00928
# 4/4 [==============================] - 3s 775ms/step - loss: 0.0107 - val_loss: 0.0041
# Epoch 67/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 67: loss did not improve from 0.00928
# 4/4 [==============================] - 3s 776ms/step - loss: 0.0111 - val_loss: 0.0028
# Epoch 68/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 68: loss did not improve from 0.00928
# 4/4 [==============================] - 4s 1s/step - loss: 0.0118 - val_loss: 0.0029
# Epoch 69/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 69: loss did not improve from 0.00928
# 4/4 [==============================] - 5s 1s/step - loss: 0.0107 - val_loss: 0.0048
# Epoch 70/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 70: loss did not improve from 0.00928
# 4/4 [==============================] - 4s 990ms/step - loss: 0.0100 - val_loss: 0.0027
# Epoch 71/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 71: loss did not improve from 0.00928
# 4/4 [==============================] - 5s 1s/step - loss: 0.0103 - val_loss: 0.0059
# Epoch 72/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 72: loss did not improve from 0.00928
# 4/4 [==============================] - 4s 909ms/step - loss: 0.0096 - val_loss: 0.0027
# Epoch 73/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 73: loss improved from 0.00928 to 0.00918, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 1s/step - loss: 0.0092 - val_loss: 0.0052
# Epoch 74/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 74: loss did not improve from 0.00918
# 4/4 [==============================] - 5s 1s/step - loss: 0.0104 - val_loss: 0.0039
# Epoch 75/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 75: loss did not improve from 0.00918
# 4/4 [==============================] - 3s 791ms/step - loss: 0.0092 - val_loss: 0.0027
# Epoch 76/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 76: loss improved from 0.00918 to 0.00893, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 829ms/step - loss: 0.0089 - val_loss: 0.0039
# Epoch 77/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 77: loss did not improve from 0.00893
# 4/4 [==============================] - 4s 907ms/step - loss: 0.0096 - val_loss: 0.0027
# Epoch 78/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 78: loss did not improve from 0.00893
# 4/4 [==============================] - 4s 859ms/step - loss: 0.0092 - val_loss: 0.0057
# Epoch 79/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 79: loss did not improve from 0.00893
# 4/4 [==============================] - 3s 808ms/step - loss: 0.0110 - val_loss: 0.0029
# Epoch 80/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 80: loss did not improve from 0.00893
# 4/4 [==============================] - 3s 818ms/step - loss: 0.0100 - val_loss: 0.0045
# Epoch 81/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0105
# Epoch 81: loss did not improve from 0.00893
# 4/4 [==============================] - 4s 864ms/step - loss: 0.0105 - val_loss: 0.0053
# Epoch 82/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 82: loss did not improve from 0.00893
# 4/4 [==============================] - 3s 812ms/step - loss: 0.0103 - val_loss: 0.0028
# Epoch 83/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 83: loss did not improve from 0.00893
# 4/4 [==============================] - 4s 852ms/step - loss: 0.0094 - val_loss: 0.0044
# Epoch 84/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 84: loss improved from 0.00893 to 0.00854, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 851ms/step - loss: 0.0085 - val_loss: 0.0027
# Epoch 85/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 85: loss did not improve from 0.00854
# 4/4 [==============================] - 3s 759ms/step - loss: 0.0104 - val_loss: 0.0030
# Epoch 86/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 86: loss improved from 0.00854 to 0.00813, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 794ms/step - loss: 0.0081 - val_loss: 0.0048
# Epoch 87/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 87: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 789ms/step - loss: 0.0087 - val_loss: 0.0027
# Epoch 88/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 88: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 815ms/step - loss: 0.0083 - val_loss: 0.0043
# Epoch 89/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 89: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 839ms/step - loss: 0.0084 - val_loss: 0.0028
# Epoch 90/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 90: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 1s/step - loss: 0.0088 - val_loss: 0.0033
# Epoch 91/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 91: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 986ms/step - loss: 0.0087 - val_loss: 0.0031
# Epoch 92/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 92: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 865ms/step - loss: 0.0088 - val_loss: 0.0026
# Epoch 93/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 93: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 1s/step - loss: 0.0101 - val_loss: 0.0029
# Epoch 94/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 94: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 1s/step - loss: 0.0090 - val_loss: 0.0027
# Epoch 95/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 95: loss did not improve from 0.00813
# 4/4 [==============================] - 5s 1s/step - loss: 0.0084 - val_loss: 0.0032
# Epoch 96/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 96: loss did not improve from 0.00813
# 4/4 [==============================] - 5s 1s/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 97/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 97: loss did not improve from 0.00813
# 4/4 [==============================] - 7s 2s/step - loss: 0.0098 - val_loss: 0.0030
# Epoch 98/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 98: loss did not improve from 0.00813
# 4/4 [==============================] - 5s 991ms/step - loss: 0.0088 - val_loss: 0.0034
# Epoch 99/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 99: loss did not improve from 0.00813
# 4/4 [==============================] - 4s 887ms/step - loss: 0.0095 - val_loss: 0.0027
# Epoch 100/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 100: loss did not improve from 0.00813
# 4/4 [==============================] - 3s 784ms/step - loss: 0.0087 - val_loss: 0.0028
# Epoch 101/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 101: loss did not improve from 0.00813
# 4/4 [==============================] - 3s 804ms/step - loss: 0.0083 - val_loss: 0.0028
# Epoch 102/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 102: loss did not improve from 0.00813
# 4/4 [==============================] - 3s 834ms/step - loss: 0.0084 - val_loss: 0.0031
# Epoch 103/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 103: loss improved from 0.00813 to 0.00783, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 104/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 104: loss did not improve from 0.00783
# 4/4 [==============================] - 9s 2s/step - loss: 0.0084 - val_loss: 0.0037
# Epoch 105/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 105: loss did not improve from 0.00783
# 4/4 [==============================] - 7s 1s/step - loss: 0.0081 - val_loss: 0.0029
# Epoch 106/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 106: loss did not improve from 0.00783
# 4/4 [==============================] - 10s 3s/step - loss: 0.0094 - val_loss: 0.0052
# Epoch 107/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 107: loss did not improve from 0.00783
# 4/4 [==============================] - 6s 1s/step - loss: 0.0096 - val_loss: 0.0025
# Epoch 108/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 108: loss did not improve from 0.00783
# 4/4 [==============================] - 5s 1s/step - loss: 0.0084 - val_loss: 0.0027
# Epoch 109/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 109: loss did not improve from 0.00783
# 4/4 [==============================] - 9s 3s/step - loss: 0.0087 - val_loss: 0.0049
# Epoch 110/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 110: loss improved from 0.00783 to 0.00760, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 12s 3s/step - loss: 0.0076 - val_loss: 0.0028
# Epoch 111/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 111: loss did not improve from 0.00760
# 4/4 [==============================] - 10s 2s/step - loss: 0.0084 - val_loss: 0.0027
# Epoch 112/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 112: loss did not improve from 0.00760
# 4/4 [==============================] - 7s 2s/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 113/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 113: loss improved from 0.00760 to 0.00742, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 0.0074 - val_loss: 0.0031
# Epoch 114/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 114: loss improved from 0.00742 to 0.00733, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 0.0073 - val_loss: 0.0027
# Epoch 115/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 115: loss did not improve from 0.00733
# 4/4 [==============================] - 4s 968ms/step - loss: 0.0084 - val_loss: 0.0025
# Epoch 116/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 116: loss did not improve from 0.00733
# 4/4 [==============================] - 4s 1s/step - loss: 0.0082 - val_loss: 0.0031
# Epoch 117/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 117: loss improved from 0.00733 to 0.00718, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 0.0072 - val_loss: 0.0026
# Epoch 118/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 118: loss did not improve from 0.00718
# 4/4 [==============================] - 5s 1s/step - loss: 0.0088 - val_loss: 0.0034
# Epoch 119/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 119: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 976ms/step - loss: 0.0078 - val_loss: 0.0027
# Epoch 120/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 120: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 946ms/step - loss: 0.0083 - val_loss: 0.0028
# Epoch 121/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 121: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 982ms/step - loss: 0.0077 - val_loss: 0.0029
# Epoch 122/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 122: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 1s/step - loss: 0.0076 - val_loss: 0.0026
# Epoch 123/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 123: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 1s/step - loss: 0.0079 - val_loss: 0.0032
# Epoch 124/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 124: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 1s/step - loss: 0.0074 - val_loss: 0.0028
# Epoch 125/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 125: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 1s/step - loss: 0.0075 - val_loss: 0.0026
# Epoch 126/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 126: loss did not improve from 0.00718
# 4/4 [==============================] - 5s 1s/step - loss: 0.0079 - val_loss: 0.0043
# Epoch 127/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 127: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 1s/step - loss: 0.0082 - val_loss: 0.0025
# Epoch 128/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 128: loss did not improve from 0.00718
# 4/4 [==============================] - 5s 1s/step - loss: 0.0083 - val_loss: 0.0067
# Epoch 129/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 129: loss did not improve from 0.00718
# 4/4 [==============================] - 5s 1s/step - loss: 0.0095 - val_loss: 0.0023
# Epoch 130/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 130: loss did not improve from 0.00718
# 4/4 [==============================] - 5s 982ms/step - loss: 0.0080 - val_loss: 0.0027
# Epoch 131/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 131: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 941ms/step - loss: 0.0082 - val_loss: 0.0032
# Epoch 132/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 132: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 993ms/step - loss: 0.0073 - val_loss: 0.0024
# Epoch 133/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 133: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 875ms/step - loss: 0.0074 - val_loss: 0.0030
# Epoch 134/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 134: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 879ms/step - loss: 0.0079 - val_loss: 0.0026
# Epoch 135/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 135: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 874ms/step - loss: 0.0072 - val_loss: 0.0025
# Epoch 136/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 136: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 889ms/step - loss: 0.0074 - val_loss: 0.0023
# Epoch 137/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 137: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 981ms/step - loss: 0.0073 - val_loss: 0.0028
# Epoch 138/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 138: loss did not improve from 0.00718
# 4/4 [==============================] - 4s 918ms/step - loss: 0.0074 - val_loss: 0.0024
# Epoch 139/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 139: loss improved from 0.00718 to 0.00711, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 1s/step - loss: 0.0071 - val_loss: 0.0037
# Epoch 140/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 140: loss did not improve from 0.00711
# 4/4 [==============================] - 4s 960ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 141/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 141: loss did not improve from 0.00711
# 4/4 [==============================] - 4s 981ms/step - loss: 0.0083 - val_loss: 0.0023
# Epoch 142/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 142: loss did not improve from 0.00711
# 4/4 [==============================] - 4s 916ms/step - loss: 0.0082 - val_loss: 0.0023
# Epoch 143/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 143: loss improved from 0.00711 to 0.00683, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 1s/step - loss: 0.0068 - val_loss: 0.0051
# Epoch 144/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 144: loss did not improve from 0.00683
# 4/4 [==============================] - 4s 851ms/step - loss: 0.0081 - val_loss: 0.0024
# Epoch 145/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 145: loss did not improve from 0.00683
# 4/4 [==============================] - 4s 1s/step - loss: 0.0073 - val_loss: 0.0039
# Epoch 146/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 146: loss did not improve from 0.00683
# 4/4 [==============================] - 4s 1s/step - loss: 0.0075 - val_loss: 0.0023
# Epoch 147/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 147: loss improved from 0.00683 to 0.00660, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 805ms/step - loss: 0.0066 - val_loss: 0.0025
# Epoch 148/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 148: loss did not improve from 0.00660
# 4/4 [==============================] - 4s 1s/step - loss: 0.0076 - val_loss: 0.0038
# Epoch 149/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 149: loss did not improve from 0.00660
# 4/4 [==============================] - 4s 902ms/step - loss: 0.0079 - val_loss: 0.0025
# Epoch 150/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 150: loss did not improve from 0.00660
# 4/4 [==============================] - 5s 1s/step - loss: 0.0074 - val_loss: 0.0024
# Epoch 151/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 151: loss did not improve from 0.00660
# 4/4 [==============================] - 4s 1s/step - loss: 0.0080 - val_loss: 0.0040
# Epoch 152/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 152: loss did not improve from 0.00660
# 4/4 [==============================] - 4s 957ms/step - loss: 0.0077 - val_loss: 0.0022
# Epoch 153/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 153: loss improved from 0.00660 to 0.00610, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 786ms/step - loss: 0.0061 - val_loss: 0.0044
# Epoch 154/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 154: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 626ms/step - loss: 0.0070 - val_loss: 0.0027
# Epoch 155/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 155: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 678ms/step - loss: 0.0081 - val_loss: 0.0034
# Epoch 156/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 156: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 739ms/step - loss: 0.0071 - val_loss: 0.0025
# Epoch 157/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 157: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 644ms/step - loss: 0.0077 - val_loss: 0.0022
# Epoch 158/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 158: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 642ms/step - loss: 0.0070 - val_loss: 0.0037
# Epoch 159/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 159: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0069 - val_loss: 0.0023
# Epoch 160/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 160: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 714ms/step - loss: 0.0074 - val_loss: 0.0027
# Epoch 161/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 161: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 661ms/step - loss: 0.0066 - val_loss: 0.0022
# Epoch 162/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 162: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0073 - val_loss: 0.0023
# Epoch 163/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 163: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 763ms/step - loss: 0.0069 - val_loss: 0.0026
# Epoch 164/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 164: loss did not improve from 0.00610
# 4/4 [==============================] - 4s 837ms/step - loss: 0.0063 - val_loss: 0.0022
# Epoch 165/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 165: loss did not improve from 0.00610
# 4/4 [==============================] - 4s 874ms/step - loss: 0.0064 - val_loss: 0.0025
# Epoch 166/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 166: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 806ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 167/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 167: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 776ms/step - loss: 0.0068 - val_loss: 0.0024
# Epoch 168/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 168: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 792ms/step - loss: 0.0065 - val_loss: 0.0022
# Epoch 169/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 169: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 721ms/step - loss: 0.0062 - val_loss: 0.0026
# Epoch 170/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 170: loss did not improve from 0.00610
# 4/4 [==============================] - 3s 745ms/step - loss: 0.0063 - val_loss: 0.0022
# Epoch 171/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 171: loss improved from 0.00610 to 0.00576, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 850ms/step - loss: 0.0058 - val_loss: 0.0020
# Epoch 172/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 172: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 804ms/step - loss: 0.0062 - val_loss: 0.0031
# Epoch 173/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 173: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0068 - val_loss: 0.0022
# Epoch 174/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 174: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 669ms/step - loss: 0.0063 - val_loss: 0.0025
# Epoch 175/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 175: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 631ms/step - loss: 0.0064 - val_loss: 0.0022
# Epoch 176/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 176: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 720ms/step - loss: 0.0067 - val_loss: 0.0041
# Epoch 177/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 177: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 690ms/step - loss: 0.0069 - val_loss: 0.0024
# Epoch 178/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 178: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 630ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 179/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 179: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 688ms/step - loss: 0.0065 - val_loss: 0.0025
# Epoch 180/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 180: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 758ms/step - loss: 0.0066 - val_loss: 0.0022
# Epoch 181/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 181: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 800ms/step - loss: 0.0066 - val_loss: 0.0023
# Epoch 182/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 182: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 697ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 183/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 183: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 667ms/step - loss: 0.0067 - val_loss: 0.0041
# Epoch 184/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 184: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 770ms/step - loss: 0.0069 - val_loss: 0.0020
# Epoch 185/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 185: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 743ms/step - loss: 0.0069 - val_loss: 0.0020
# Epoch 186/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 186: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 767ms/step - loss: 0.0062 - val_loss: 0.0032
# Epoch 187/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 187: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0064 - val_loss: 0.0022
# Epoch 188/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 188: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 683ms/step - loss: 0.0065 - val_loss: 0.0020
# Epoch 189/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 189: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 656ms/step - loss: 0.0074 - val_loss: 0.0025
# Epoch 190/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 190: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 680ms/step - loss: 0.0070 - val_loss: 0.0022
# Epoch 191/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 191: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 682ms/step - loss: 0.0074 - val_loss: 0.0020
# Epoch 192/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 192: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 701ms/step - loss: 0.0064 - val_loss: 0.0036
# Epoch 193/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 193: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 753ms/step - loss: 0.0061 - val_loss: 0.0023
# Epoch 194/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 194: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 677ms/step - loss: 0.0060 - val_loss: 0.0023
# Epoch 195/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 195: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 665ms/step - loss: 0.0061 - val_loss: 0.0019
# Epoch 196/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 196: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 634ms/step - loss: 0.0069 - val_loss: 0.0034
# Epoch 197/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 197: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 656ms/step - loss: 0.0063 - val_loss: 0.0022
# Epoch 198/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 198: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 744ms/step - loss: 0.0064 - val_loss: 0.0019
# Epoch 199/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 199: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 805ms/step - loss: 0.0064 - val_loss: 0.0028
# Epoch 200/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 200: loss did not improve from 0.00576
# 4/4 [==============================] - 4s 837ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 201/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 201: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 740ms/step - loss: 0.0059 - val_loss: 0.0035
# Epoch 202/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 202: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 765ms/step - loss: 0.0059 - val_loss: 0.0019
# Epoch 203/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 203: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 792ms/step - loss: 0.0062 - val_loss: 0.0020
# Epoch 204/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 204: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 829ms/step - loss: 0.0060 - val_loss: 0.0025
# Epoch 205/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 205: loss did not improve from 0.00576
# 4/4 [==============================] - 4s 891ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 206/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 206: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 813ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 207/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 207: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0067 - val_loss: 0.0019
# Epoch 208/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 208: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 684ms/step - loss: 0.0068 - val_loss: 0.0023
# Epoch 209/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 209: loss did not improve from 0.00576
# 4/4 [==============================] - 3s 737ms/step - loss: 0.0070 - val_loss: 0.0033
# Epoch 210/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 210: loss improved from 0.00576 to 0.00554, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 755ms/step - loss: 0.0055 - val_loss: 0.0029
# Epoch 211/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 211: loss did not improve from 0.00554
# 4/4 [==============================] - 3s 786ms/step - loss: 0.0065 - val_loss: 0.0041
# Epoch 212/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 212: loss did not improve from 0.00554
# 4/4 [==============================] - 4s 932ms/step - loss: 0.0065 - val_loss: 0.0019
# Epoch 213/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 213: loss did not improve from 0.00554
# 4/4 [==============================] - 4s 936ms/step - loss: 0.0062 - val_loss: 0.0039
# Epoch 214/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 214: loss did not improve from 0.00554
# 4/4 [==============================] - 4s 903ms/step - loss: 0.0067 - val_loss: 0.0022
# Epoch 215/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 215: loss did not improve from 0.00554
# 4/4 [==============================] - 6s 2s/step - loss: 0.0059 - val_loss: 0.0025
# Epoch 216/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 216: loss did not improve from 0.00554
# 4/4 [==============================] - 5s 1s/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 217/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 217: loss did not improve from 0.00554
# 4/4 [==============================] - 4s 942ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 218/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 218: loss did not improve from 0.00554
# 4/4 [==============================] - 4s 1s/step - loss: 0.0059 - val_loss: 0.0031
# Epoch 219/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 219: loss did not improve from 0.00554
# 4/4 [==============================] - 4s 930ms/step - loss: 0.0059 - val_loss: 0.0018
# Epoch 220/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 220: loss did not improve from 0.00554
# 4/4 [==============================] - 4s 860ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 221/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 221: loss did not improve from 0.00554
# 4/4 [==============================] - 4s 964ms/step - loss: 0.0064 - val_loss: 0.0028
# Epoch 222/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0054
# ...
# Epoch 624: loss did not improve from 0.00304
# 4/4 [==============================] - 5s 1s/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 625/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 625: loss did not improve from 0.00304
# 4/4 [==============================] - 6s 1s/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 626/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 626: loss did not improve from 0.00304
# 4/4 [==============================] - 4s 827ms/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 627/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 627: loss did not improve from 0.00304
# 4/4 [==============================] - 3s 698ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 628/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 628: loss did not improve from 0.00304
# 4/4 [==============================] - 3s 662ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 629/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 629: loss did not improve from 0.00304
# 4/4 [==============================] - 3s 702ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 630/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 630: loss did not improve from 0.00304
# 4/4 [==============================] - 3s 640ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 631/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 631: loss did not improve from 0.00304
# 4/4 [==============================] - 3s 670ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 632/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 632: loss did not improve from 0.00304
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 633/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 633: loss did not improve from 0.00304
# 4/4 [==============================] - 3s 695ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 634/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 634: loss did not improve from 0.00304
# 4/4 [==============================] - 3s 676ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 635/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 635: loss improved from 0.00304 to 0.00295, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 3s 727ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 636/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 636: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 671ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 637/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 637: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 668ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 638/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 638: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 639/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 639: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 731ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 640/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 640: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 677ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 641/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 641: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 668ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 642/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 642: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 646ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 643/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 643: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 632ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 644/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 644: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 703ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 645/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 645: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 646/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 646: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 691ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 647/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 647: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 620ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 648/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 648: loss did not improve from 0.00295
# 4/4 [==============================] - 2s 583ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 649/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 649: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 701ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 650/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 650: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 623ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 651/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 651: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 606ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 652/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 652: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 622ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 653/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 653: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 796ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 654/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 654: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 740ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 655/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 655: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 752ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 656/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 656: loss did not improve from 0.00295
# 4/4 [==============================] - 4s 1s/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 657/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 657: loss did not improve from 0.00295
# 4/4 [==============================] - 5s 1s/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 658/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 658: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 659/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 659: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 671ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 660/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 660: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 598ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 661/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 661: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 688ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 662/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 662: loss did not improve from 0.00295
# 4/4 [==============================] - 4s 702ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 663/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 663: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 799ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 664/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 664: loss did not improve from 0.00295
# 4/4 [==============================] - 5s 1s/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 665/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 665: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 725ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 666/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 666: loss did not improve from 0.00295
# 4/4 [==============================] - 4s 947ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 667/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 667: loss did not improve from 0.00295
# 4/4 [==============================] - 4s 930ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 668/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 668: loss did not improve from 0.00295
# 4/4 [==============================] - 5s 1s/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 669/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 669: loss did not improve from 0.00295
# 4/4 [==============================] - 4s 962ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 670/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 670: loss did not improve from 0.00295
# 4/4 [==============================] - 4s 902ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 671/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 671: loss did not improve from 0.00295
# 4/4 [==============================] - 4s 1s/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 672/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 672: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 743ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 673/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 673: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 674ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 674/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 674: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 642ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 675/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 675: loss did not improve from 0.00295
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 676/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 676: loss improved from 0.00295 to 0.00293, saving model to LSTM(GOOG).hdf5
# 4/4 [==============================] - 4s 1s/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 677/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 677: loss did not improve from 0.00293
# 4/4 [==============================] - 4s 1s/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 678/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 678: loss did not improve from 0.00293
# 4/4 [==============================] - 4s 1s/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 679/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 679: loss did not improve from 0.00293
# 4/4 [==============================] - 5s 1s/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 680/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 680: loss did not improve from 0.00293
# 4/4 [==============================] - 4s 852ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 681/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 681: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 733ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 682/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 682: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 702ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 683/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 683: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 656ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 684/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 684: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 680ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 685/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 685: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 623ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 686/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 686: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 621ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 687/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 687: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 688/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 688: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 717ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 689/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 689: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 791ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 690/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 690: loss did not improve from 0.00293
# 4/4 [==============================] - 4s 886ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 691/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 691: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 630ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 692/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 692: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 698ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 693/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 693: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 717ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 694/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 694: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 644ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 695/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 695: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 696/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 696: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 686ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 697/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 697: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 692ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 698/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 698: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 684ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 699/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 699: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 700/700
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 700: loss did not improve from 0.00293
# 4/4 [==============================] - 3s 647ms/step - loss: 0.0035 - val_loss: 0.0011

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
predictions = lstm_model.predict(features_set)
mse = mean_squared_error(labels, predictions)
mae = mean_absolute_error(labels, predictions)
r2 = r2_score(labels, predictions)
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
print(f'R-squared Score: {r2}')
# Out:
# 38/38 [==============================] - 5s 52ms/step
# Mean Squared Error: 0.0010197972840008496
# Mean Absolute Error: 0.024211096193434135
# R-squared Score: 0.9876473221456094

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
model=load_model(f'LSTM({stock_name}).hdf5')
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
train = data[:train_dataset_len]
valid = data[train_dataset_len:]
valid_values=valid.values
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(20,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
print(predictions)
print(rmse)

model.summary()
# Out:
# 6/6 [==============================] - 3s 44ms/step
# C:\Users\rking\AppData\Local\Temp\ipykernel_2164\148972974.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions
# [[ 98.42878 ]
#  [100.52509 ]
#  [102.10768 ]
#  [103.18745 ]
#  [103.84251 ]
#  [103.89976 ]
#  [103.30645 ]
#  [102.38274 ]
#  [101.44358 ]
#  [100.9658  ]
#  [101.14831 ]
#  [101.828064]
#  [102.64719 ]
#  [103.68327 ]
#  [104.64136 ]
#  [105.21576 ]
#  [105.27514 ]
#  [105.23994 ]
#  [105.49524 ]
#  [105.787895]
#  [105.79914 ]
#  [105.49062 ]
#  [105.10272 ]
#  [104.83226 ]
#  [104.83112 ]
#  [104.86707 ]
#  [104.78299 ]
#  [104.94403 ]
#  [105.43827 ]
#  [106.06194 ]
#  [106.433136]
#  [106.4462  ]
#  [106.12166 ]
#  [105.72568 ]
#  [105.64673 ]
#  [105.930916]
#  [106.830025]
#  [108.61254 ]
#  [110.9814  ]
#  [113.18535 ]
#  [115.01457 ]
#  [116.496475]
#  [117.82057 ]
#  [118.94736 ]
#  [120.05634 ]
#  [120.84521 ]
#  [121.03116 ]
#  [120.98936 ]
#  [121.10747 ]
#  [121.38605 ]
#  [121.58157 ]
#  [121.69845 ]
#  [121.86196 ]
#  [122.239075]
#  [122.90878 ]
#  [123.20295 ]
#  [122.91008 ]
#  [122.26238 ]
#  [121.739815]
#  [121.57772 ]
#  [121.743286]
#  [122.21779 ]
#  [122.6569  ]
#  [122.85462 ]
#  [122.55517 ]
#  [122.1464  ]
#  [121.827225]
#  [121.28007 ]
#  [120.4942  ]
#  [119.872215]
#  [119.5101  ]
#  [119.469086]
#  [119.618866]
#  [120.01544 ]
#  [120.385666]
#  [120.48689 ]
#  [119.99041 ]
#  [119.1224  ]
#  [118.42693 ]
#  [118.67753 ]
#  [119.91933 ]
#  [121.53189 ]
#  [122.78841 ]
#  [123.256874]
#  [122.7081  ]
#  [121.586525]
#  [120.59328 ]
#  [120.17751 ]
#  [121.036804]
#  [122.9167  ]
#  [125.35558 ]
#  [127.64174 ]
#  [129.12941 ]
#  [129.37297 ]
#  [128.69333 ]
#  [127.66062 ]
#  [127.11    ]
#  [127.258446]
#  [127.698654]
#  [128.08272 ]
#  [128.25627 ]
#  [128.40483 ]
#  [128.44612 ]
#  [128.2525  ]
#  [128.0295  ]
#  [127.6753  ]
#  [127.31691 ]
#  [127.144   ]
#  [127.55309 ]
#  [128.14934 ]
#  [128.62286 ]
#  [128.96985 ]
#  [129.60168 ]
#  [130.65984 ]
#  [131.92484 ]
#  [132.9922  ]
#  [133.63766 ]
#  [133.73459 ]
#  [133.53674 ]
#  [133.40265 ]
#  [133.52077 ]
#  [133.6635  ]
#  [133.85231 ]
#  [134.22311 ]
#  [134.63716 ]
#  [135.0282  ]
#  [135.31943 ]
#  [135.03741 ]
#  [133.92783 ]
#  [132.36613 ]
#  [130.98312 ]
#  [129.8583  ]
#  [129.24358 ]
#  [129.30437 ]
#  [129.70341 ]
#  [130.45134 ]
#  [131.1442  ]
#  [131.85513 ]
#  [132.50781 ]
#  [133.2962  ]
#  [134.23131 ]
#  [135.09479 ]
#  [135.98007 ]
#  [136.65623 ]
#  [136.83794 ]
#  [136.80002 ]
#  [136.81001 ]
#  [136.76033 ]
#  [136.59348 ]
#  [136.1231  ]
#  [135.57994 ]
#  [135.39853 ]
#  [134.22385 ]
#  [131.71336 ]
#  [128.59453 ]
#  [126.00503 ]
#  [124.48272 ]
#  [124.22844 ]
#  [124.968376]
#  [126.28353 ]
#  [127.730644]
#  [129.00491 ]
#  [129.9955  ]
#  [130.4921  ]
#  [130.79178 ]
#  [131.02748 ]
#  [131.42522 ]
#  [132.06088 ]
#  [133.02458 ]
#  [133.90216 ]
#  [134.5357  ]
#  [134.96243 ]
#  [135.3729  ]
#  [135.59602 ]
#  [135.57608 ]
#  [135.45415 ]
#  [135.10956 ]
#  [134.35951 ]
#  [133.32819 ]
#  [132.03877 ]
#  [130.93575 ]
#  [130.17645 ]
#  [130.50044 ]
#  [131.57787 ]
#  [132.58168 ]
#  [132.97118 ]
#  [132.79742 ]
#  [132.27336 ]]
# 4.0242164657173545
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 128)           66560
#
#  dropout (Dropout)           (None, 60, 128)           0
#
#  lstm_1 (LSTM)               (None, 60, 64)            49408
#
#  dropout_1 (Dropout)         (None, 60, 64)            0
#
#  lstm_2 (LSTM)               (None, 60, 64)            33024
#
#  dropout_2 (Dropout)         (None, 60, 64)            0
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 161441 (630.63 KB)
# Trainable params: 161441 (630.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Assuming test_data contains the last 60 days of the available data
x_test = []
x_test.append(test_data[-60:])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
predictions = []

for _ in range(15):
        # Predict the next day
        prediction = lstm_model.predict(x_test)
        
        # Append the prediction to the results
        predictions.append(prediction[0, 0])

        # Update x_test for the next prediction
        x_test = np.roll(x_test, -1, axis=1)
        x_test[0, -1, 0] = prediction

    # Inverse transform the predictions to get actual stock prices
predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
plt.plot(predictions)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - ETA: 0s
# C:\Users\rking\AppData\Local\Temp\ipykernel_2164\3836994191.py:17: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0, -1, 0] = prediction
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step

# %%
print(predictions)
# Out:
# [[135.28079]
#  [135.20189]
#  [135.51614]
#  [136.02798]
#  [136.56923]
#  [137.05585]
#  [137.46994]
#  [137.824  ]
#  [138.13712]
#  [138.42244]
#  [138.68697]
#  [138.93259]
#  [139.1595 ]
#  [139.36754]
#  [139.55688]
#  [139.72887]
#  [139.88512]
#  [140.02753]
#  [140.15845]
#  [140.28026]
#  [140.39505]
#  [140.50491]
#  [140.61137]
#  [140.71585]
#  [140.82054]
#  [140.92555]
#  [141.03137]
#  [141.13818]
#  [141.24629]
#  [141.35536]
#  [141.46518]
#  [141.5753 ]
#  [141.68532]
#  [141.79471]
#  [141.90298]
#  [142.00978]
#  [142.11441]
#  [142.2166 ]
#  [142.31587]
#  [142.41199]
#  [142.50458]
#  [142.59381]
#  [142.67938]
#  [142.7613 ]
#  [142.83963]
#  [142.91461]
#  [142.98628]
#  [143.05478]
#  [143.12048]
#  [143.18356]
#  [143.24417]
#  [143.30261]
#  [143.35881]
#  [143.41312]
#  [143.46521]
#  [143.51576]
#  [143.56485]
#  [143.61253]
#  [143.65884]
#  [143.70393]
#  [143.7478 ]
#  [143.79045]
#  [143.83199]
#  [143.8724 ]
#  [143.9117 ]
#  [143.94986]
#  [143.98691]
#  [144.02287]
#  [144.05774]
#  [144.09154]
#  [144.12425]
#  [144.15591]
#  [144.18652]
#  [144.21611]
#  [144.24469]
#  [144.2723 ]
#  [144.29892]
#  [144.32463]
#  [144.34943]
#  [144.37338]
#  [144.39648]
#  [144.41878]
#  [144.4403 ]
#  [144.46109]
#  [144.48116]
#  [144.50055]
#  [144.51926]
#  [144.53737]
#  [144.55489]
#  [144.5718 ]]
